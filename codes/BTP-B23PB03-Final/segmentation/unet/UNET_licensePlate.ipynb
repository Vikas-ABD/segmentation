# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="WQIX3N0AouohId9nmwju")
project = rf.workspace("work-gorze").project("licence_plate_segmentation_india")
dataset = project.version(1).download("png-mask-semantic")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.6-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 1.6 MB/s eta 0:00:00
# Collecting certifi==2022.12.7 (from roboflow)
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 8.8 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 20.0 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.14.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.4)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.42.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.2.0)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.2)
# Installing collected packages: python-dotenv, pyparsing, opencv-python-headless, idna, cycler, chardet, certifi, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.0.76
#     Uninstalling opencv-python-headless-4.8.0.76:
#       Successfully uninstalled opencv-python-headless-4.8.0.76
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
# Successfully installed certifi-2022.12.7 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-1.0.0 roboflow-1.1.6 supervision-0.14.0
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in licence_plate_segmentation_india-1 to png-mask-semantic:: 100%|██████████| 111774/111774 [00:06<00:00, 18192.62it/s]
# Extracting Dataset Version Zip to licence_plate_segmentation_india-1 in png-mask-semantic:: 100%|██████████| 3526/3526 [00:00<00:00, 5158.78it/s]

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda




################################################################
def multi_unet_model1(n_classes=2, IMG_H=416, IMG_W=416, IMG_CHANNELS=3):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    #model.summary()

    return model

# %%
# !mkdir mask

# %%
import os
import shutil

# Replace these paths with your actual source and destination folder paths
source_folder = '/content/licence_plate_segmentation_india-1/train/'
destination_folder = '/content/mask'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Iterate through the files in the source folder
for filename in os.listdir(source_folder):
    if filename.endswith('_mask.png'):  # Assuming mask images end with '_mask.png'
        source_path = os.path.join(source_folder, filename)
        destination_path = os.path.join(destination_folder, filename)
        shutil.move(source_path, destination_path)
        print(f"Moved {filename} to {destination_folder}")
# Out:
# Moved GA2_jpg.rf.46f8dcc9ecff708a02fe77d788fe61be_mask.png to /content/mask
# Moved 1a0da3dc-6667-4092-bc2a-a541a06f1e90___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano9_jpg.rf.0118bf9bbbfbc5cd8b80ab483b682c6c_mask.png to /content/mask
# Moved video2_5260_jpg.rf.06fdca044e12a958f65415e21fad1e18_mask.png to /content/mask
# Moved GA9_jpg.rf.413ace678293f7c3a984aadff28ffe6e_mask.png to /content/mask
# Moved DN7_jpg.rf.ed5c0a40aa0febc1a50b1bb11becaed6_mask.png to /content/mask
# Moved video3_1700_jpg.rf.81459b98d4cee25a83c2334fec827beb_mask.png to /content/mask
# Moved video11_2800_jpg.rf.101352b10f2291901019b892af595fc1_mask.png to /content/mask
# Moved video4_2420_jpg.rf.f3a0dbd782e391b49b681b2670861757_mask.png to /content/mask
# Moved GJ16_jpg.rf.5cf1b7d04c4e6150f9e401bb86d5329b_mask.png to /content/mask
# Moved 20210506_14_10_30_000_csn5ZBbKQsPS82BdtEmUny6qhf52_F_3000_4000_jpg.rf.f9c7dea75a61416111261b72487a90b1_mask.png to /content/mask
# Moved video2_820_jpg.rf.24d91bc3dad4cc7faf6a1e6b49d83b72_mask.png to /content/mask
# Moved video2_3440_jpg.rf.c931c81c0d2481dc28a1e8516123d0bb_mask.png to /content/mask
# Moved video11_4660_jpg.rf.876a39564c5a0dd5e68f504cbeba25bf_mask.png to /content/mask
# Moved video3_1440_jpg.rf.eb0a12d4b8671069295a7c9a2115183c_mask.png to /content/mask
# Moved DL8_jpg.rf.548c1b16bb3240d8575467fceeb09feb_mask.png to /content/mask
# Moved 07aaab79-71ee-4ea3-a9e6-640191183947___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_1208484d1392541449-nissan-terrano-official-review-img_20140215_181708_jpg.rf
# Moved video4_2130_jpg.rf.c1f6af96d6d8b5c471fcc43f28dc46eb_mask.png to /content/mask
# Moved video3_1100_jpg.rf.6b7800ed200b1a0b77af26274851d66b_mask.png to /content/mask
# Moved video5_350_jpg.rf.69a25ce7f71536f71705ad50da2e3e67_mask.png to /content/mask
# Moved HR14_jpg.rf.271a1da4d6ba3f92c2973162645d9e39_mask.png to /content/mask
# Moved JH12_jpg.rf.a5ba82832bfd682fe6310417e85fdff9_mask.png to /content/mask
# Moved video2_400_jpg.rf.54559589a0d36fd7ccf67e4495164918_mask.png to /content/mask
# Moved video3_2240_jpg.rf.330be5dd39be4d8f04a337e78f683eee_mask.png to /content/mask
# Moved video3_1770_jpg.rf.d68e43751245790638c1b138bb3d3742_mask.png to /content/mask
# Moved video11_4030_jpg.rf.775ca473af0374500009804023e2aed8_mask.png to /content/mask
# Moved HR4_jpg.rf.edb5c7ef6d560111173e6e496a1bfb23_mask.png to /content/mask
# Moved video3_1090_jpg.rf.d64dac9d2d47eddfbc9dc55bc10db2d7_mask.png to /content/mask
# Moved video12_80_jpg.rf.082543d80bea88f0ba2123087d6ae8cd_mask.png to /content/mask
# Moved video11_790_jpg.rf.af81404233edcc22a463ba53964aebff_mask.png to /content/mask
# Moved video11_3720_jpg.rf.3ea7b5bc5849c56e870bfa10d7439b6d_mask.png to /content/mask
# Moved video4_2600_jpg.rf.acedf2ceb2f49a0b4867b13d65e22858_mask.png to /content/mask
# Moved video11_3830_jpg.rf.752643447e09c4289319bf5a5e6fbbf9_mask.png to /content/mask
# Moved GJ17_jpg.rf.8cd81107a09988a2109a037b4d3a3f74_mask.png to /content/mask
# Moved video2_4780_jpg.rf.e9b35f3959f142f52c6750626268abbb_mask.png to /content/mask
# Moved 20210427_19_51_59_000_xXhVe7Y5ShaVIcJB0hKzZOwzj0u2_F_3000_4000_jpg.rf.e8fb37da78a60440fdbf9b12946a62e7_mask.png to /content/mask
# Moved video2_5280_jpg.rf.dd21a2f3278a7405e967fa3b454fafa0_mask.png to /content/mask
# Moved video4_2030_jpg.rf.f243bfcccc4a4b28dbbd2c9c3b8a5534_mask.png to /content/mask
# Moved HP5_jpg.rf.0c805a1a8c8d2fbe97163876129b3b76_mask.png to /content/mask
# Moved video6_1090_jpg.rf.ce901aaba6a193d841dceb726535c037_mask.png to /content/mask
# Moved video3_610_jpg.rf.f11f5db90a3fca60126b3e4d6a17e285_mask.png to /content/mask
# Moved video4_2300_jpg.rf.621275e738199fbbc3fa93a0f3705d4e_mask.png to /content/mask
# Moved video11_2770_jpg.rf.ecfb5a26d8a4985be07ea1fd590f5999_mask.png to /content/mask
# Moved HR8_jpg.rf.62b80438a189bc32b142f3dafa91a1fd_mask.png to /content/mask
# Moved video11_3260_jpg.rf.21d16e7b03e6e5a0e1c975fb09311e30_mask.png to /content/mask
# Moved video4_2600_jpg.rf.70596bba6cffff66db7519e7602f024d_mask.png to /content/mask
# Moved video4_2370_jpg.rf.877f02c6ad822c07d9b7574523f88cd1_mask.png to /content/mask
# Moved HR17_jpg.rf.5aa0f81f600a777e306c3f755df85475_mask.png to /content/mask
# Moved video11_2680_jpg.rf.dc5a04d0815a50a754367476d602b910_mask.png to /content/mask
# Moved video2_220_jpg.rf.87b3c3ad00f20c55a2b328d97853313a_mask.png to /content/mask
# Moved video2_480_jpg.rf.a7452688cd1a36cd2897776a27230675_mask.png to /content/mask
# Moved 20210503_08_41_00_000_KSEQZniS5WMCLLUe5Fg2kbdAq8X2_F_4160_3120_jpg.rf.9b3311021ec68e74d5162a0c1838f507_mask.png to /content/mask
# Moved video2_4370_jpg.rf.5324c000c9bc439ad3a9425611959974_mask.png to /content/mask
# Moved video11_4440_jpg.rf.28715ef625d939931c58822adc0d9cf2_mask.png to /content/mask
# Moved video11_4620_jpg.rf.4fd3cbb51900efe384bdea8a080c383a_mask.png to /content/mask
# Moved video4_3310_jpg.rf.99fa0d1de7fae9ca2dbdb32b0b66b637_mask.png to /content/mask
# Moved f16274c4-0d3d-4c85-9dcc-5ac71734b281___speedex-number-plates-nandanam-chennai-car-number-plate-dealers-1ofla74-jpg_jpeg.rf.c1d7d9dd4015fdcb15c86a745123e45c_mask.png to /content/mask
# Moved video11_770_jpg.rf.80761e200ace23c2816a87466f0909c0_mask.png to /content/mask
# Moved video4_1100_jpg.rf.14ec7d6c11e270db805c6c593c22211e_mask.png to /content/mask
# Moved video4_1100_jpg.rf.9a75f9e74d654eec28246b1cfbba9925_mask.png to /content/mask
# Moved video4_2410_jpg.rf.abb4a8736ac94de9f4e39b3040aaf929_mask.png to /content/mask
# Moved video2_4290_jpg.rf.645e9cd3dba02e7d8c732b8a31c5f583_mask.png to /content/mask
# Moved GA13_jpg.rf.41038b9e72867236ac5dc3e4cbc20ba0_mask.png to /content/mask
# Moved video3_40_jpg.rf.058897fa801c1622599b9afc344f2bce_mask.png to /content/mask
# Moved f7ba7a93-e8d7-4253-b327-d87e3f2bb747___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_2013-Nissan-Terrano-Rear_jpg.rf.03ce41a0bf5a95e49681b630c93aa782_mask.png to /content/mask
# Moved video3_620_jpg.rf.1dd170fa0e91af5aa3e402f9968c73ca_mask.png to /content/mask
# Moved video3_1130_jpg.rf.931bc856b67236561d8c54e93fe7d9d6_mask.png to /content/mask
# Moved JH1_jpg.rf.5895ed439ab76572f227b657cbe913e2_mask.png to /content/mask
# Moved video2_240_jpg.rf.ee85069ef91f0cfc60ff456ba9e70423_mask.png to /content/mask
# Moved video12_90_jpg.rf.38de4388399e062a41da52dba9496d3e_mask.png to /content/mask
# Moved HP11_jpg.rf.bc3724ef2c8f6b311b591d9c51b2b897_mask.png to /content/mask
# Moved GJ15_jpg.rf.a1b4a811ebe87368865a6697825c75d6_mask.png to /content/mask
# Moved video3_1680_jpg.rf.8310c4bc908a67f4e75749ac724a65f1_mask.png to /content/mask
# Moved 13ffaad4-a186-46bd-ae5d-924d1c8d7c50___maruti-suzuki-Baleno-RS-pics-48-jpg_jpeg.rf.750f88562c8ca195a3b2af81a6af5c7f_mask.png to /content/mask
# Moved video4_3820_jpg.rf.6f8e67d5bd4e6ec1a342aed5bb293b40_mask.png to /content/mask
# Moved video4_2500_jpg.rf.a7f68c33af6be619e44d6772a618b57c_mask.png to /content/mask
# Moved video5_470_jpg.rf.61cab757a07207118d31518373aa35c0_mask.png to /content/mask
# Moved video4_2490_jpg.rf.bf84ad95db3c5250ad14af3aad6ad2b8_mask.png to /content/mask
# Moved video11_4080_jpg.rf.97397a9ca7898b1eec814b60f05b73af_mask.png to /content/mask
# Moved video2_1750_jpg.rf.64c49553985b087bd105b80f7290bb8d_mask.png to /content/mask
# Moved video3_1780_jpg.rf.89e8dd04dfb50c0ca0cf1b393681737b_mask.png to /content/mask
# Moved video4_340_jpg.rf.267fe15224c1d40d246bba034ee29dbe_mask.png to /content/mask
# Moved video3_440_jpg.rf.331f117edeb162772ff47ecb1afc424d_mask.png to /content/mask
# Moved video5_400_jpg.rf.6c743a558b232428ef9a78748e28bc84_mask.png to /content/mask
# Moved video3_560_jpg.rf.095cb6e74da32865baf3e57bceeb15ab_mask.png to /content/mask
# Moved video4_2440_jpg.rf.4daa2177f3b8e8d14cd35972fef4f279_mask.png to /content/mask
# Moved video12_90_jpg.rf.c987bc0dd49ff1b5266c2da6c89dc242_mask.png to /content/mask
# Moved video4_2650_jpg.rf.4e5165e7227f21ab97ec1c0a9a2c8099_mask.png to /content/mask
# Moved e354039f-d73c-4f12-9df5-f0129345fa79___scorpio-JPG_jpeg.rf.1827dd4a10f52d1014b5c727e8dd6b3e_mask.png to /content/mask
# Moved GJ10_jpg.rf.0191a355df876585863119d9c06199bf_mask.png to /content/mask
# Moved video4_3200_jpg.rf.94561d2b3b2cc5c472cb8a7af752fa05_mask.png to /content/mask
# Moved video2_220_jpg.rf.4a3f5421ffd9e53fd5da25db7958dc5a_mask.png to /content/mask
# Moved e719f39b-e8dd-4fe0-9a41-71123932a486___226676869_4_1000x700_maruti-suzuki-wagon-r-duo-petrol-120000-kms-2007-year-cars_rev001-jpg_jpeg.rf.299d8d35e1a38429e5da8468c5d2456d_mask.png to /content/mask
# Moved video4_2600_jpg.rf.409285371ef9c868e99260efee8fa7e4_mask.png to /content/mask
# Moved video3_660_jpg.rf.b5f1ada2250255aac9b93870b8c0e58d_mask.png to /content/mask
# Moved 20210503_08_41_00_000_KSEQZniS5WMCLLUe5Fg2kbdAq8X2_F_4160_3120_jpg.rf.3cf80a20febc368283de6fbd63f3a0bc_mask.png to /content/mask
# Moved video12_110_jpg.rf.49ae795088013f017aa631d48eb1cb09_mask.png to /content/mask
# Moved video11_2670_jpg.rf.02417860f2fbe94f37ab9a3c8c289af9_mask.png to /content/mask
# Moved video2_480_jpg.rf.51a0847564c48bb1d835b8e49278bad4_mask.png to /content/mask
# Moved video5_80_jpg.rf.bebb2bf1e9c20b59cfb8337d824466f6_mask.png to /content/mask
# Moved e29b6eea-504a-4da2-8503-5bd3443f3bd8___maruti-suzuki-wagon-r-front-left-rim-jpg_jpeg.rf.a6c0525904a1d842d1fabe334edfd485_mask.png to /content/mask
# Moved video11_2760_jpg.rf.f974b9d4fc601bf8c3001dbb5d1f07ec_mask.png to /content/mask
# Moved video3_1930_jpg.rf.1762bdfc7d8ae4d94d5ea8d6e94e25ad_mask.png to /content/mask
# Moved video4_2250_jpg.rf.010c35d5c11dd37f708f02dcd58c30fc_mask.png to /content/mask
# Moved video6_1040_jpg.rf.fd64b24d5286f49b49826e2ccb372d96_mask.png to /content/mask
# Moved video2_300_jpg.rf.1122ceae2613cae7c6c35a4f7863b27e_mask.png to /content/mask
# Moved HP8_jpg.rf.75d10d84c083a1ed6ab51ab343f59dd5_mask.png to /content/mask
# Moved video3_1070_jpg.rf.cdb708d15556e64c2c8420250805f324_mask.png to /content/mask
# Moved 07bd977e-d578-49a2-b345-7cee5a4db6bf___new_1031520d1356604430-skoda-rapid-joins-family-edit-sold-wp_000281-jpg_jpeg.rf.50df28460897de02ae1e5a171a2e4778_mask.png to /content/mask
# Moved video4_3130_jpg.rf.2dc2112355143440c59357cbee3ba3e2_mask.png to /content/mask
# Moved video11_2680_jpg.rf.bb759ea944cd86c7d498009f06efd8af_mask.png to /content/mask
# Moved video3_1190_jpg.rf.9ee6ebe58f64805f285459ae9d65c62b_mask.png to /content/mask
# Moved video4_2780_jpg.rf.7989053672a05737a9c03f1a7d0f3fdb_mask.png to /content/mask
# Moved HP21_jpg.rf.03eff68f373ba60b9709e562fcd23554_mask.png to /content/mask
# Moved video4_2610_jpg.rf.b04e0ce57e9fd32e7b805c698c94b738_mask.png to /content/mask
# Moved video5_180_jpg.rf.cbea303a490e49b28f706f9566a50d63_mask.png to /content/mask
# Moved 0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740-jpg_jpeg.rf.14b7bec636d5c9057b2c1000405b5d9d_mask.png to /content/mask
# Moved video11_3940_jpg.rf.f31362abf66119df43d1fab08f4e0f43_mask.png to /content/mask
# Moved video3_570_jpg.rf.cfe9837c0849893b88ff6d485537af3d_mask.png to /content/mask
# Moved f5bbb8da-dddd-47ae-a46c-15492f9cf752___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_10187746544_0c0822790e_jpg.rf.a8fdc0ac7dd20e5eb66d5e1f594ef19a_mask.png to /content/mask
# Moved GJ28_jpg.rf.b1f8c83f18f0d7aecf32544fcf811950_mask.png to /content/mask
# Moved video11_770_jpg.rf.279c33a5ab5285f897d52cda16493fab_mask.png to /content/mask
# Moved video4_3830_jpg.rf.1a7bc0cca4d811b2df838c481b7321ca_mask.png to /content/mask
# Moved video2_4770_jpg.rf.ac3f33d7d8a18948d41649062e05fec3_mask.png to /content/mask
# Moved video4_3280_jpg.rf.ba91b167a9b7dfebafc8526802da2529_mask.png to /content/mask
# Moved video4_2720_jpg.rf.21def0564ffbb829b6e6c7e84ddcea53_mask.png to /content/mask
# Moved video2_820_jpg.rf.97362b4774f67e37f164cf3855240aac_mask.png to /content/mask
# Moved video2_180_jpg.rf.ef22e886de3d4405c6bff3014969b3e1_mask.png to /content/mask
# Moved HR6_jpg.rf.9b1a958b9b0b162ac321b1f380cbffa1_mask.png to /content/mask
# Moved video12_70_jpg.rf.ee81c2fe035deeaca4ebaeb8336bf01b_mask.png to /content/mask
# Moved HR21_jpg.rf.f658c14d82939170a221322c6c070ed9_mask.png to /content/mask
# Moved video2_1490_jpg.rf.c7fd7c4e1541d98cbdb70a1ceb3a8b73_mask.png to /content/mask
# Moved e53076d3-c3b7-47b8-8c63-30a08b8ad983___40213__Maruti_Suzuki_Swift-016-JPG_jpeg.rf.ffd8e09dc625f112164bca1972ba76ba_mask.png to /content/mask
# Moved video2_620_jpg.rf.b1d1b2376ed75a3a7c0a2bb44fff9298_mask.png to /content/mask
# Moved video2_3560_jpg.rf.219c124930d1941ee5df635a96435a2e_mask.png to /content/mask
# Moved video3_1960_jpg.rf.47d184165da90eada44dbd18617b2447_mask.png to /content/mask
# Moved HR15_jpg.rf.f0ddbf34e9f771dd99f5c06455d6b538_mask.png to /content/mask
# Moved video5_1830_jpg.rf.62a9516ed5394ab003af297da6e0c605_mask.png to /content/mask
# Moved video4_3280_jpg.rf.2e4d49fd0e608ac3e8d7491202508a01_mask.png to /content/mask
# Moved video3_1840_jpg.rf.1b156cde007819e08e9415ce05d06e3e_mask.png to /content/mask
# Moved e53076d3-c3b7-47b8-8c63-30a08b8ad983___40213__Maruti_Suzuki_Swift-016-JPG_jpeg.rf.6d6a6c80467bdeae1f0aead074d1eb2c_mask.png to /content/mask
# Moved video2_4140_jpg.rf.79d799311acbbff8494506b6e203c348_mask.png to /content/mask
# Moved video11_860_jpg.rf.b1427e0ebdfac5bc7e1bcc1bd563af9b_mask.png to /content/mask
# Moved video2_610_jpg.rf.9b5aabfc60d028b2d79bc2482ead93fd_mask.png to /content/mask
# Moved fd0140cc-e887-43b8-a439-24877ea77670___Maruti-Suzuki-Baleno-Number-Plates-Design-jpg_jpeg.rf.efad9e94395647a531d60b2cd46c15a2_mask.png to /content/mask
# Moved video4_3780_jpg.rf.74cf3427da51913f2e1e1563c48bdc7d_mask.png to /content/mask
# Moved video2_4190_jpg.rf.00ca4eb297eca005fe4060be9afabcd4_mask.png to /content/mask
# Moved video5_60_jpg.rf.e761f5eaafb2011d35de50ffe95f1720_mask.png to /content/mask
# Moved video5_60_jpg.rf.9e1cc34028519ea6d9b9bcea2896b8f0_mask.png to /content/mask
# Moved video2_3990_jpg.rf.e92a702edf5427e1b794fc3119130f86_mask.png to /content/mask
# Moved video11_780_jpg.rf.e392d4998c81606fba2d494d8107e2ef_mask.png to /content/mask
# Moved HR8_jpg.rf.3ff7209f22192fa0a50ecee11887ed41_mask.png to /content/mask
# Moved 20210428_18_18_35_000_uA7x1XuBPngcHFRu7KambGvmgt62_F_5632_4224_jpg.rf.5f98666025aa7c816cfe681400759cbe_mask.png to /content/mask
# Moved video4_2210_jpg.rf.4a8638f389283e23cdd22722a56bd809_mask.png to /content/mask
# Moved video11_4440_jpg.rf.52bc46a10c809e6cebe42a8c6306f187_mask.png to /content/mask
# Moved fc1f58f0-2f54-4545-8915-2936d08dcce1___new_Skoda_Laura_DSG_Long_Term_Review-125-jpg_jpeg.rf.f9b6e7a80788ea1cbd0f85b649f94823_mask.png to /content/mask
# Moved video3_1920_jpg.rf.3e3c5855e7b7ce05306bff54959383a8_mask.png to /content/mask
# Moved video4_2970_jpg.rf.958d5e1d40d1281e4bb928f577ff7402_mask.png to /content/mask
# Moved 20210503_06_08_06_000_ovRKxW0QbBVfwN9RW4teROP1YgG3_F_4160_3120_jpg.rf.5d5d47ed493eebc9f1e1f76d8c50a9ea_mask.png to /content/mask
# Moved video11_4730_jpg.rf.2e55e19141b2410561587ec34932ad95_mask.png to /content/mask
# Moved DN8_jpg.rf.127bed18e401b0bb7e306c219bd219fa_mask.png to /content/mask
# Moved video2_280_jpg.rf.6ea4e5a69af4dd47feafebc055fe91e4_mask.png to /content/mask
# Moved video3_2220_jpg.rf.56c7a5951cb1e65009006b17d1e8561f_mask.png to /content/mask
# Moved video3_1460_jpg.rf.8c79ecf72d10b5877d489ec1a290c506_mask.png to /content/mask
# Moved HR5_jpg.rf.947d46da190748031af09ae1a395b4e8_mask.png to /content/mask
# Moved video2_4520_jpg.rf.86233e0afb364bdad002b40af5c5fa25_mask.png to /content/mask
# Moved 20210430_06_00_21_000_ovRKxW0QbBVfwN9RW4teROP1YgG3_F_4160_3120_jpg.rf.33d4714e849c98f762a7fa8ae99cf0cd_mask.png to /content/mask
# Moved video11_4750_jpg.rf.6173f15565145a2f904d660420415efa_mask.png to /content/mask
# Moved video11_2830_jpg.rf.ad7be8578e9d0b774290dc51d29ece28_mask.png to /content/mask
# Moved video4_3770_jpg.rf.ee0594710c35c5d6e6c289b603fa904a_mask.png to /content/mask
# Moved 07064c2c-2aa3-4419-91a4-92916de8e54c___mahindra-scorpio-old-car-500x500-jpg_jpeg.rf.e7e7b8ac87c28fb1c47cab97648cc1d2_mask.png to /content/mask
# Moved video5_80_jpg.rf.acc903b5d48f525dd417aca5c700b669_mask.png to /content/mask
# Moved video3_1750_jpg.rf.efcf343b5c62af7c44979d48eb45ffec_mask.png to /content/mask
# Moved video6_1140_jpg.rf.46f6f98e21168eb6b3d1545f0f50c138_mask.png to /content/mask
# Moved video4_50_jpg.rf.e494bceafd2761ee13670509064abc96_mask.png to /content/mask
# Moved video3_1680_jpg.rf.2baa375b713b0d7c665d4d46839477aa_mask.png to /content/mask
# Moved video2_4280_jpg.rf.bce268d0671b9994a47241eb016e7782_mask.png to /content/mask
# Moved video4_3310_jpg.rf.8cfd49012635aa89bb04e6d0d0e6410b_mask.png to /content/mask
# Moved 07064c2c-2aa3-4419-91a4-92916de8e54c___mahindra-scorpio-old-car-500x500-jpg_jpeg.rf.8cc800ae46ca45a098ba5debfcbf5949_mask.png to /content/mask
# Moved video2_1590_jpg.rf.a5d4b4e81139d912f3f3c72e3eba7c8d_mask.png to /content/mask
# Moved video11_2820_jpg.rf.31b1ec366cba9068301fd94fe366844c_mask.png to /content/mask
# Moved 0b24d6ed-d32f-420d-bc18-03deece29073___2015-Maruti-Ciaz-Test-Drive-Review-jpg_jpeg.rf.79af8d69f9fa868d4541fd0a5381693e_mask.png to /content/mask
# Moved video5_500_jpg.rf.57909cc54fb32f359ef088a7c268e4d5_mask.png to /content/mask
# Moved video2_4080_jpg.rf.821020ac1d497fd7cad93071a5e47a68_mask.png to /content/mask
# Moved video2_2210_jpg.rf.eb550221c13ed1c1a7856c659dd6ca33_mask.png to /content/mask
# Moved 20210429_11_49_33_000_fIZoRQmuZyVkc7oDgq1fjezTvCu1_F_4160_3120_jpg.rf.c44b7e9246213e7f460b6ddbaa50f20f_mask.png to /content/mask
# Moved HR13_jpg.rf.a229ba5a399a94b3e2470c6fd840d3ac_mask.png to /content/mask
# Moved video11_4440_jpg.rf.a934976659745186cee5c5aada1cf457_mask.png to /content/mask
# Moved 20210502_05_59_35_000_ovRKxW0QbBVfwN9RW4teROP1YgG3_F_4160_3120_jpg.rf.d531f3135d2484648c8ec0421280d062_mask.png to /content/mask
# Moved GA7_jpg.rf.01a578b68c1cc044739ff4d49e929df1_mask.png to /content/mask
# Moved video11_3250_jpg.rf.85ec28570a433ed492ba62d7633e2941_mask.png to /content/mask
# Moved video5_480_jpg.rf.f28bc392526560e03087ae8405036a5e_mask.png to /content/mask
# Moved GA5_jpg.rf.900d5dc64aef3c1ac04b61ceb568c310_mask.png to /content/mask
# Moved video11_2800_jpg.rf.fc193b00c44c32fb1b9ca46f9b8fb616_mask.png to /content/mask
# Moved video11_760_jpg.rf.89f5c05641a32ef315352283025ad9e3_mask.png to /content/mask
# Moved video4_2240_jpg.rf.3bb052b5a388f02058d0343fd5a44cba_mask.png to /content/mask
# Moved video5_390_jpg.rf.aa360d67aa7c9ecd717d731616af68b0_mask.png to /content/mask
# Moved HR6_jpg.rf.0eacaf017835647325b1e05039db5340_mask.png to /content/mask
# Moved video2_820_jpg.rf.966218888fb168e0f3872ffa23631a99_mask.png to /content/mask
# Moved video3_1080_jpg.rf.9c3eef3ee912f503decf0681dbbba966_mask.png to /content/mask
# Moved video2_4010_jpg.rf.276825973b024a2cbba9b2c87f813e3f_mask.png to /content/mask
# Moved video3_2190_jpg.rf.29927a2e129aacb5fd7436949aabdfb3_mask.png to /content/mask
# Moved HP14_jpg.rf.37ee361aeefc22602b1e0e11ba40a5be_mask.png to /content/mask
# Moved video4_2650_jpg.rf.89ba7e4dc82e5b2bdc0358b767de9081_mask.png to /content/mask
# Moved video6_1150_jpg.rf.abd6eb7c58428b042c1725d2ce6eed74_mask.png to /content/mask
# Moved video11_4810_jpg.rf.4178c937229b2dcf8abfc1e4d7c40aa1_mask.png to /content/mask
# Moved video4_50_jpg.rf.86b86f7f3202579e66a955d68f95d6c7_mask.png to /content/mask
# Moved GJ20_jpg.rf.b72eb91fb46c2c3e83f39f37aad9b2e2_mask.png to /content/mask
# Moved video5_70_jpg.rf.ff761e117e615dd811a39409e9dcbe32_mask.png to /content/mask
# Moved video4_2790_jpg.rf.aeecb23eed5b564558b410467aa63d36_mask.png to /content/mask
# Moved video11_3300_jpg.rf.3531c631f4b4e4c68010950b7429fa34_mask.png to /content/mask
# Moved video4_2830_jpg.rf.794d987ea29684b30e91f9437e442017_mask.png to /content/mask
# Moved video11_4070_jpg.rf.10d7209b122d97ee3826fdbbf7559099_mask.png to /content/mask
# Moved video6_1080_jpg.rf.20a7f58ba2d5ac180e51239316d0f090_mask.png to /content/mask
# Moved video3_1790_jpg.rf.fc90c281e8f78352ff98c1e54ea81ec8_mask.png to /content/mask
# Moved video5_360_jpg.rf.63e812b8d967637541ba4cb2a374490c_mask.png to /content/mask
# Moved video6_210_jpg.rf.65cba2f547fed534ec17fff23bf01dd5_mask.png to /content/mask
# Moved GJ17_jpg.rf.ac48a362601e8d22a93549538cd0de81_mask.png to /content/mask
# Moved video4_2140_jpg.rf.2caf0d5202a0233d75a1b548e65dd645_mask.png to /content/mask
# Moved video11_2700_jpg.rf.d4d378788f009f1e04aa498a90e013e9_mask.png to /content/mask
# Moved video5_190_jpg.rf.b17d30ac667eb1a2a3552ebe05018cd1_mask.png to /content/mask
# Moved HR7_jpg.rf.febb40bcdc2052f8e3f715f743b5b504_mask.png to /content/mask
# Moved video6_1000_jpg.rf.3ba27f744ec250c1e0f75c92fb0bd57d_mask.png to /content/mask
# Moved video3_1370_jpg.rf.4e44e6f935232277b9f34dc8e570cfa4_mask.png to /content/mask
# Moved video11_4410_jpg.rf.34348f4487955efe410add73f2c04d8b_mask.png to /content/mask
# Moved video5_170_jpg.rf.9f333ac74359abd85b1d61da0664e49f_mask.png to /content/mask
# Moved video11_4470_jpg.rf.84434e2a2e6980de17a78a8499fa35db_mask.png to /content/mask
# Moved HP13_jpg.rf.0345ff857ed2ade0f2b9e5187dbe25f4_mask.png to /content/mask
# Moved JH1_jpg.rf.af3766ff84e5fcdb3075bf3a357fdf22_mask.png to /content/mask
# Moved video2_5270_jpg.rf.12c12d2c7220f32d72be0add27427ece_mask.png to /content/mask
# Moved video2_1590_jpg.rf.671fff16c3edbb4dd2b190b25950f88c_mask.png to /content/mask
# Moved fac9f4e6-c4b9-4872-86da-79d58ea2adc5___5273-jpg_jpeg.rf.a9005ff134184b4143662a25a8daa714_mask.png to /content/mask
# Moved video4_3130_jpg.rf.aab194773ca201dbd1fc191294c3ee63_mask.png to /content/mask
# Moved video3_2200_jpg.rf.dd5c5bc5c8efbf55cfcc1d562048a59b_mask.png to /content/mask
# Moved video4_2370_jpg.rf.06968bea8e2ed407f845b51edd659372_mask.png to /content/mask
# Moved 07aaab79-71ee-4ea3-a9e6-640191183947___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_1208484d1392541449-nissan-terrano-official-review-img_20140215_181708_jpg.rf.bf3ca28b840cb221904ecc8ce046736f_mask.png to /content/mask
# Moved HR21_jpg.rf.8c797e6c03dabeaf047470f9b26b48f2_mask.png to /content/mask
# Moved video5_430_jpg.rf.74330ed1ea8e33ac6ba6646b7d7f1dfd_mask.png to /content/mask
# Moved video3_1350_jpg.rf.58b30dfa31234da6da52a149d753c3e3_mask.png to /content/mask
# Moved video4_3800_jpg.rf.a0e2b634e9d68618c24ab2d0c416a8b5_mask.png to /content/mask
# Moved video4_2020_jpg.rf.a39b548dd9af3e3043bf795b79a1600e_mask.png to /content/mask
# Moved HR12_jpg.rf.518062f1d6fbaa5948e16e0cb943bba2_mask.png to /content/mask
# Moved 20210429_14_22_24_000_M0qQbjq7mhasETXjCQGvnoZxK3a2_F_4160_3120_jpg.rf.1d552f4a4e06d4b123c4902ab0d51e5d_mask.png to /content/mask
# Moved video3_2210_jpg.rf.9d2b55c9c9d34509374a8fea674380a4_mask.png to /content/mask
# Moved DL9_jpg.rf.b5531374d09c1bbcf7bcc3f69153ba8b_mask.png to /content/mask
# Moved video11_2790_jpg.rf.12008d934a4d33c7841e92481761a310_mask.png to /content/mask
# Moved HP18_jpg.rf.0fab7ea934304a7d0d446670d6d97b68_mask.png to /content/mask
# Moved video3_310_jpg.rf.dee45a1f2d82cf8df8b104194fa641a4_mask.png to /content/mask
# Moved HP4_jpg.rf.15a504dcfe8d91a950d238bee651fc1e_mask.png to /content/mask
# Moved 125b5cda-9691-47aa-8e57-f6d8a8537d83___fancy_number_plates_in_india-jpg_jpeg.rf.cb99d5df14b0dae36f012336aa205d7f_mask.png to /content/mask
# Moved video3_610_jpg.rf.12662dabd304990a5dbe603dd2af0958_mask.png to /content/mask
# Moved ed9cd3b2-76a2-4cc8-9e4e-76d50ad1ff68___maruti-suzuki-wagon-r-hood-open-view-jpg_jpeg.rf.5e8484aa68883c34ba870dfbab34d35a_mask.png to /content/mask
# Moved video2_310_jpg.rf.dd988d664396ddb7081f10c1343ae41d_mask.png to /content/mask
# Moved video11_4010_jpg.rf.fef3e3d8a2d535318731f8d81e9aef58_mask.png to /content/mask
# Moved e53076d3-c3b7-47b8-8c63-30a08b8ad983___40213__Maruti_Suzuki_Swift-016-JPG_jpeg.rf.74729e2053a00f913d46a8ce3d72c0d6_mask.png to /content/mask
# Moved video6_1110_jpg.rf.d91d3746768edb40f52a0bceabb93cf4_mask.png to /content/mask
# Moved video4_2230_jpg.rf.85a44e8c6e3918af31989cb9993a237c_mask.png to /content/mask
# Moved video2_4780_jpg.rf.ac9e95f40ae9d6266c6354c962838d39_mask.png to /content/mask
# Moved video11_4960_jpg.rf.4d971442506ad7d6493ae00ae1db6bb5_mask.png to /content/mask
# Moved video11_790_jpg.rf.e5e7a1e0cf1ba2624015cf1b188ffacc_mask.png to /content/mask
# Moved video5_370_jpg.rf.3bde7bcfca88100f32c0c4289cdc1c03_mask.png to /content/mask
# Moved video11_3310_jpg.rf.979cdfaf959839ec93310ac5b970f1cb_mask.png to /content/mask
# Moved video3_1870_jpg.rf.a487b1c41140433d14109724625726c3_mask.png to /content/mask
# Moved video3_650_jpg.rf.c82571518411421582dc4c8e80b83cde_mask.png to /content/mask
# Moved video12_100_jpg.rf.b191efa9973b823cf65d58766e7f89fc_mask.png to /content/mask
# Moved video3_610_jpg.rf.c44e2804c6cc2fe2a7772982eb55478f_mask.png to /content/mask
# Moved GJ2_jpg.rf.de1ebf161de5c112bcc1bc61e39ffb23_mask.png to /content/mask
# Moved GJ8_jpg.rf.bac1028a89c79eca2435b05a9eba3014_mask.png to /content/mask
# Moved video3_1180_jpg.rf.96860b67927c8ff51a1adbc2393c953f_mask.png to /content/mask
# Moved 20210505_07_54_14_000_T4CaxysrQ7W21Wgl1wZWBCtdRjE3_F_3264_2448_jpg.rf.4603b275bf8c6b37cfe2925aa6828217_mask.png to /content/mask
# Moved video2_4870_jpg.rf.b13addba63f72c0c419ca40b326b0970_mask.png to /content/mask
# Moved video2_4760_jpg.rf.72506ba9d49784ae8ed12ff5b29c2975_mask.png to /content/mask
# Moved video2_2230_jpg.rf.2c7d784a2be6e98829299fff5f973b31_mask.png to /content/mask
# Moved video3_1050_jpg.rf.df4ce06bc07ba21af58b21105d86a50e_mask.png to /content/mask
# Moved video3_2000_jpg.rf.d159c2b69347e7556ee141179cda60aa_mask.png to /content/mask
# Moved DL8_jpg.rf.c23d65a0888f1d09e3db480535786d55_mask.png to /content/mask
# Moved video2_4370_jpg.rf.7d044a79310b0a64f6eaba2a97a1cab9_mask.png to /content/mask
# Moved e663fa35-ce3c-401d-8451-30edd236b3e4___maxresdefault2-jpg_jpeg.rf.559e36c9ed823df42c9538f530fce0fc_mask.png to /content/mask
# Moved video2_3990_jpg.rf.68e3994ab2dd5d5b8b857fde8f4e4663_mask.png to /content/mask
# Moved video4_3780_jpg.rf.ca33c5586ad3172cb47009d602d768b1_mask.png to /content/mask
# Moved GA9_jpg.rf.6ccb85d1e564dd8485435126a295c577_mask.png to /content/mask
# Moved video11_550_jpg.rf.8087e4bbb41a9b47b2964f8e591f6dbd_mask.png to /content/mask
# Moved video3_1370_jpg.rf.7899a672c8130efd27767703b05fdd8e_mask.png to /content/mask
# Moved video5_470_jpg.rf.c2246f258f0442460c25c5e2bdc8350b_mask.png to /content/mask
# Moved DL5_jpg.rf.a16e4f9b3bc8892ea9ad857d99bb12ca_mask.png to /content/mask
# Moved video6_1070_jpg.rf.d7bf4f13a4b87274f067ef5cde8cf8ce_mask.png to /content/mask
# Moved video3_2180_jpg.rf.c2f172369db5905d62d206633652cd79_mask.png to /content/mask
# Moved video3_2210_jpg.rf.ebb96a91abf4902d625d3a5997a93ea5_mask.png to /content/mask
# Moved ec4bde57-11dd-4d59-96ae-b5d3b28afda5___Maruti-Suzuki-Celerio-Back-Number-Plates-Design-jpg_jpeg.rf.ab8d3278062bc31bacae1dd604a4b2cb_mask.png to /content/mask
# Moved 175ff546-0679-4cbb-ab03-acfcd96877b7___Maruti_Wagon_R_Rear-jpg_jpeg.rf.7402529d7b9cc5f6bfbc128905184a1e_mask.png to /content/mask
# Moved 18f2e55e-0724-4eee-a28e-5d552a5aa045___20455d0e2dca458f13fbf4da5a2dc118-jpg-Copy_jpeg.rf.2e9f26477bcfe7a949b653839d4e2bd9_mask.png to /content/mask
# Moved DL34_jpg.rf.58f19049ec1e8ab6c572c11ad9f5beb1_mask.png to /content/mask
# Moved DL5_jpg.rf.7c16085916362b75a5eff9a8a426456d_mask.png to /content/mask
# Moved video4_2660_jpg.rf.f9c6e3fb9801bd5456e2cf7ca9d194ba_mask.png to /content/mask
# Moved GJ11_jpg.rf.11f73cf6db9617779f098663add2b2ed_mask.png to /content/mask
# Moved video3_570_jpg.rf.c625f09a790f1e3edb42fec514ba7648_mask.png to /content/mask
# Moved video11_4070_jpg.rf.f6f2e905d162572a338fd8863c096d85_mask.png to /content/mask
# Moved HR11_jpg.rf.0632eb3c98c7030de87782f770e08ef5_mask.png to /content/mask
# Moved 00b42b2c-f193-4863-b92c-0245cbc816da___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-Petrol-Review-Images-Black-Front-Angle_jpg.rf.33f2e9dcb226b5457fd800eb1718dd7a_mask.png to /content/mask
# Moved 20210501_16_09_55_000_xQNCrIqS3UW13K3s7IVYpWimydF2_T_3000_4000_jpg.rf.127932320cab3203649eb316822ce470_mask.png to /content/mask
# Moved video4_3790_jpg.rf.466023956c51c0780812e3626d3ce026_mask.png to /content/mask
# Moved HR5_jpg.rf.8c53f08a12ac3eb4c34f83a4690225e7_mask.png to /content/mask
# Moved GJ17_jpg.rf.bddc0c440ee59f07acd42a86844cf10b_mask.png to /content/mask
# Moved video4_2140_jpg.rf.0d83bca8123c7a50bd88d803d5cb859b_mask.png to /content/mask
# Moved GA11_jpg.rf.02c3ab0dc2ffdbdd9538d05dd9a0e1db_mask.png to /content/mask
# Moved video11_800_jpg.rf.1e0a7c35e987b3486f37621ef8cae6f1_mask.png to /content/mask
# Moved video11_3340_jpg.rf.2911e0790ed877d919c7205d8ed70df3_mask.png to /content/mask
# Moved 0850c175-0b8d-47f2-801c-e29f1dbdb367___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_571_jpg.rf.0ae0047e2007835968d482c7b7642ac0_mask.png to /content/mask
# Moved video6_200_jpg.rf.9f7d67c022efe59c7ebf00478ea6413e_mask.png to /content/mask
# Moved DL32_jpg.rf.160959ff7406fc74916d5e2c6a250478_mask.png to /content/mask
# Moved video2_1830_jpg.rf.3dcb7f76b10f40138276e63bdd27d980_mask.png to /content/mask
# Moved DN5_jpg.rf.cda49702dc3fe245a3a0020eda234375_mask.png to /content/mask
# Moved video2_4400_jpg.rf.883fd645c032fe13d0d63fc5911acd89_mask.png to /content/mask
# Moved 0a720df9-e4ef-4e44-8c13-b39b9be8444d___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-6_jpg.rf.a2b92bfa502ddba2096be14d4af1facf_mask.png to /content/mask
# Moved video2_4280_jpg.rf.b390142b08189bf09bfc675f0226dce4_mask.png to /content/mask
# Moved video5_520_jpg.rf.053ad44c246097a23646aee85949c580_mask.png to /content/mask
# Moved video3_1930_jpg.rf.caebaca788f9b83550eb9dd04d6a82af_mask.png to /content/mask
# Moved video4_2170_jpg.rf.427e262a76b71d5f391428d7e3834dab_mask.png to /content/mask
# Moved DL5_jpg.rf.c271c05c85ec46e1305ceb3228e42590_mask.png to /content/mask
# Moved video5_370_jpg.rf.98159243446eae67aa90af92cfb16733_mask.png to /content/mask
# Moved video11_4030_jpg.rf.98fee87a324bd58b09b94dc31338ae3a_mask.png to /content/mask
# Moved video3_1650_jpg.rf.fda4ddabe5637fef7dd84e7ffe64b3f3_mask.png to /content/mask
# Moved video11_3260_jpg.rf.ff3167bc55b9e3dd30cc200effd32038_mask.png to /content/mask
# Moved video4_340_jpg.rf.b63df1846835209a4a545fcd8c011ee1_mask.png to /content/mask
# Moved video2_400_jpg.rf.3a43809d95a617c0ff2a0918b441273c_mask.png to /content/mask
# Moved video4_2020_jpg.rf.22734309bd7ce6cec3d3cb514371e92e_mask.png to /content/mask
# Moved video11_4450_jpg.rf.a4842207d0be278a91cd612138115911_mask.png to /content/mask
# Moved video3_1710_jpg.rf.f6bb0908f3dc7154f3f07ead7f64993e_mask.png to /content/mask
# Moved video11_3640_jpg.rf.b9370a7a4bd798ca67491eaf8896b86d_mask.png to /content/mask
# Moved video4_2440_jpg.rf.cd1824b851a58af3e77955756d0fe3a9_mask.png to /content/mask
# Moved 03273806-bb1e-48da-8c8b-a0133a90197a___2014-Skoda-Yeti-Test-Drive-jpg_jpeg.rf.832ccca386d3b35a88d102bf5b0f5409_mask.png to /content/mask
# Moved video11_750_jpg.rf.4a0da59dcfe2efc751bfdeb111495ed5_mask.png to /content/mask
# Moved video11_3910_jpg.rf.fb0e4d7043f9ea2853b2e52a284d1efa_mask.png to /content/mask
# Moved video3_1450_jpg.rf.b0b5e18a5cf9c4ad5f47d41a03c2e3ed_mask.png to /content/mask
# Moved video2_5290_jpg.rf.9d10a328bbd08d3139434edd4c60a09d_mask.png to /content/mask
# Moved video4_2660_jpg.rf.787704a43aa0e7723502f4bffb06d6cd_mask.png to /content/mask
# Moved video4_2660_jpg.rf.1391ac839a7882a28c4f85ff13cb5000_mask.png to /content/mask
# Moved HR7_jpg.rf.e15071f479e6203d510f17378857beb8_mask.png to /content/mask
# Moved video2_4980_jpg.rf.8d434787b95499e07f53fc7b2e3dee8b_mask.png to /content/mask
# Moved GJ27_jpg.rf.28bff6cbcb63d62ded1e09d450734dd2_mask.png to /content/mask
# Moved 07aaab79-71ee-4ea3-a9e6-640191183947___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_1208484d1392541449-nissan-terrano-official-review-img_20140215_181708_jpg.rf.6d1f796eceb3a8ae75d33df1cfd77571_mask.png to /content/mask
# Moved HR9_jpg.rf.210570184969f94482391e89ff815ebf_mask.png to /content/mask
# Moved video4_2260_jpg.rf.28128a3f5224164dcc15fd18b4ad3290_mask.png to /content/mask
# Moved video4_3840_jpg.rf.f990020a151ae33820bce2672ba0277f_mask.png to /content/mask
# Moved 1f0a7fe8-ac9b-4b54-9d55-e11f34f9f98b___9f6521b2ddb7b8e40ffd510966ffcca3-jpg_jpeg.rf.b1d4b2bffca2d2dd53299b1b43af5eed_mask.png to /content/mask
# Moved video11_4600_jpg.rf.1a478d4e5388dfc816ead35bc3bf957c_mask.png to /content/mask
# Moved video6_1130_jpg.rf.820d4892441d42d70a4814524d9e8225_mask.png to /content/mask
# Moved video11_3700_jpg.rf.e52d88cf5e372c441d97856fb3eeb6d5_mask.png to /content/mask
# Moved video3_630_jpg.rf.0f67295526c9905ebdd2052be7cebe1d_mask.png to /content/mask
# Moved f265077a-611f-4a18-abe5-46518b1756e6___1232700-take-look-number-plate-uploadfromtaptalk1398055489406-jpg_jpeg.rf.67dbf1af6f593a9be1a98df0846076bf_mask.png to /content/mask
# Moved GJ6_jpg.rf.a6c6d513ffcd051f65252a8c1253056b_mask.png to /content/mask
# Moved video12_70_jpg.rf.25915254fbb8557a2236be95465658e5_mask.png to /content/mask
# Moved video2_480_jpg.rf.fdec1a5d5c2560dd8a9d074a22464286_mask.png to /content/mask
# Moved video2_310_jpg.rf.e2f42eeedca8ac70bd86af4c188d2730_mask.png to /content/mask
# Moved video2_5240_jpg.rf.781e8cf6da6ab71e5a16a1215a8ca2ff_mask.png to /content/mask
# Moved DL4_jpg.rf.1a26d7e0069c36603db2bfb671702502_mask.png to /content/mask
# Moved video2_0_jpg.rf.71c52afe7199021925daf5db14213dab_mask.png to /content/mask
# Moved video5_1830_jpg.rf.ba00181ffb197731fa5fea88d993c709_mask.png to /content/mask
# ...
# Moved video3_1200_jpg.rf.a79bbd91f4d21a73fc68744ebfd02bf9_mask.png to /content/mask
# Moved 00b42b2c-f193-4863-b92c-0245cbc816da___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-Petrol-Review-Images-Black-Front-Angle_jpg.rf.d80c83efdcfd2dc637769a5af7ad9724_mask.png to /content/mask
# Moved DN3_jpg.rf.76717ff66010d72de0cddaa70bce2fa2_mask.png to /content/mask
# Moved video3_1950_jpg.rf.ea5e49b7652fcfc23fb25fecc265b3b4_mask.png to /content/mask
# Moved video11_4780_jpg.rf.03d74913295a5d922c9c54e0c50d115d_mask.png to /content/mask
# Moved 20210503_08_41_00_000_KSEQZniS5WMCLLUe5Fg2kbdAq8X2_F_4160_3120_jpg.rf.da382d2f4951583768df4258b1a73ffa_mask.png to /content/mask
# Moved GA4_jpg.rf.a7c3d3a860755382432723d70e01dfaa_mask.png to /content/mask
# Moved DN2_jpg.rf.5539c49db4c93fca147e35209e6d5142_mask.png to /content/mask
# Moved GJ13_jpg.rf.9f904d85a2a2363f7f79aff3f0f4f46a_mask.png to /content/mask
# Moved HP4_jpg.rf.732c74164c56a4d65a2e0b8677d27b1e_mask.png to /content/mask
# Moved video2_2230_jpg.rf.80bface017da4a4d8312299d600619d3_mask.png to /content/mask
# Moved video2_4150_jpg.rf.ff530f291e256f072309377b68dbbc9e_mask.png to /content/mask
# Moved video2_650_jpg.rf.1a073069fd81b5147763713954df4ff7_mask.png to /content/mask
# Moved 20210503_06_08_06_000_ovRKxW0QbBVfwN9RW4teROP1YgG3_F_4160_3120_jpg.rf.2eae17fa129d1a2582f7c014a64d8a9d_mask.png to /content/mask
# Moved e1d7921f-5e58-46c7-b4f9-9fd4585508f1___IMG_9072-jpg_jpeg.rf.b15fc1c9417e7eb727d769399a9e2c9f_mask.png to /content/mask
# Moved video4_2780_jpg.rf.00d1c16e3b960b66a5215ce2ab580f6e_mask.png to /content/mask
# Moved video11_4950_jpg.rf.fa89b4c928606edd42440e1d05e8d0df_mask.png to /content/mask
# Moved video11_420_jpg.rf.0ce661aff4b155f8ad174d29bd54b0bb_mask.png to /content/mask
# Moved video11_3680_jpg.rf.71e2f3cfd8a884f59148e44851683ef1_mask.png to /content/mask
# Moved fbc107b7-13d8-4a2d-b8be-7c96bd7d609c___new_9214a754343030395508e104d7948167_large-jpg_jpeg.rf.88587292b5d987940df1bf938450df4f_mask.png to /content/mask
# Moved HR8_jpg.rf.f72dd5bad07ef8115d63d49c0d1c3b6e_mask.png to /content/mask
# Moved video6_210_jpg.rf.a4e7f6589cfee8bba36cc04656e61267_mask.png to /content/mask
# Moved video2_3260_jpg.rf.e85f19fe47e6c226620a3463c27bc386_mask.png to /content/mask
# Moved 0850c175-0b8d-47f2-801c-e29f1dbdb367___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_571_jpg.rf.375bab5259d22d0f59df971a269c21a8_mask.png to /content/mask
# Moved video3_1950_jpg.rf.48ad0ebe441173cf4e67e16d15d0a921_mask.png to /content/mask
# Moved video3_1050_jpg.rf.dd9fe6b496e176a4272db696b23abfe4_mask.png to /content/mask
# Moved video11_3330_jpg.rf.ae860b6d39845e378ba455ea1655e045_mask.png to /content/mask
# Moved video11_2710_jpg.rf.2d4be2e1054f47c9ef50ba5fa6c69630_mask.png to /content/mask
# Moved video11_2690_jpg.rf.8aa77431b70d2978f0e749fc5bab7de2_mask.png to /content/mask
# Moved e54fb93b-020f-4c55-b4db-86e17ba9b9e0___2014-VW-Polo-facelift-rear-spotted-testing-in-Pune-India-jpg_jpeg.rf.e55a79cff7c11949fa369ea8e2d257d5_mask.png to /content/mask
# Moved video4_3840_jpg.rf.ee76e927a8f08d938b72b0645818c72c_mask.png to /content/mask
# Moved video3_640_jpg.rf.7ababe23a075519b35a04e957fdb0e3f_mask.png to /content/mask
# Moved 20210427_12_52_47_000_pgmtGnyv84hd7BiNoFr7ALIRzeZ2_F_4160_3120_jpg.rf.d1c7875c26e27a86a1702782bf147298_mask.png to /content/mask
# Moved video4_2130_jpg.rf.356975e517f63e68589eec4e89c09ea9_mask.png to /content/mask
# Moved JH11_jpg.rf.65863be327c99e576aac1ab6765ba3b2_mask.png to /content/mask
# Moved video4_2830_jpg.rf.4b8c1517dd25eca6fa188458c8e51e22_mask.png to /content/mask
# Moved 20210508_09_01_22_000_x1Al88rRcbgbIm5Y4D4pjFVpufq2_F_4000_3000_jpg.rf.fe0fd3a004c9fc6ff04699e8c1406e78_mask.png to /content/mask
# Moved HP2_jpg.rf.5ce432b8b3319224a71548cd0e0526fd_mask.png to /content/mask
# Moved video4_2810_jpg.rf.a4342e12ad2a6818821f7222ddbfd6fd_mask.png to /content/mask
# Moved video2_3600_jpg.rf.918c724c9098a775c4f355d070390cae_mask.png to /content/mask
# Moved DL31_jpg.rf.ef852cfccbd7a5f4846a7f0b4f25c948_mask.png to /content/mask
# Moved video3_650_jpg.rf.b7304d91d509f695c7762166e515a812_mask.png to /content/mask
# Moved video5_70_jpg.rf.0bc1676bace73698dd9d3b3ab0cc3e0f_mask.png to /content/mask
# Moved video11_4610_jpg.rf.9fe358180f1fd431b0afd7711a796e21_mask.png to /content/mask
# Moved video3_1210_jpg.rf.3bd43b2bc9a342cf564e68ef3b3846c4_mask.png to /content/mask
# Moved JH11_jpg.rf.4bd710df6809516cd0880a06e673f44f_mask.png to /content/mask
# Moved video2_410_jpg.rf.20340984ec10d7bb95cfc53e51685f04_mask.png to /content/mask
# Moved video2_230_jpg.rf.33123a5fd56ce0191f722e49734d0ddf_mask.png to /content/mask
# Moved video11_4620_jpg.rf.04c8fc36206f325d1b5960d1cab6c225_mask.png to /content/mask
# Moved video11_3920_jpg.rf.816e70a14ee7bcaa4cce42d09cad0185_mask.png to /content/mask
# Moved video11_2780_jpg.rf.5d665c544f38976a8d146dd7b9bf6187_mask.png to /content/mask
# Moved HR16_jpg.rf.440e09ce755a1a5ef5d542029768c81a_mask.png to /content/mask
# Moved JH14_jpg.rf.d8903f5ace9bfd770dd4520d39aa842f_mask.png to /content/mask
# Moved HR19_jpg.rf.2ae7ea1c5cdfce02d755ad46dba80ef4_mask.png to /content/mask
# Moved video11_990_jpg.rf.3907f4e0408c1118eeab9e4e5873c94b_mask.png to /content/mask
# Moved HP7_jpg.rf.1109c1597f0e10356dbd96bb4c9008e2_mask.png to /content/mask
# Moved video2_0_jpg.rf.c160b948010705c26628c10a2ef78833_mask.png to /content/mask
# Moved GA1_jpg.rf.1271f50de71f3746eb3f5f455b7394dd_mask.png to /content/mask
# Moved video11_4430_jpg.rf.8b35f82571cadefe4959c0ba0139ee6b_mask.png to /content/mask
# Moved video11_3340_jpg.rf.c7b6559c63972fe9dfa09890d10a1518_mask.png to /content/mask
# Moved video5_140_jpg.rf.4eb1769fe808502758c663fbf4502a00_mask.png to /content/mask
# Moved video6_1100_jpg.rf.6538e481bb823f696d7d22418776b735_mask.png to /content/mask
# Moved video4_2630_jpg.rf.92d068517779aae00ca9f405c3c31049_mask.png to /content/mask
# Moved video12_70_jpg.rf.2af80d92fd46b270cb993ba61447f765_mask.png to /content/mask
# Moved video11_3880_jpg.rf.69b6660e071d033bf7b817b1427d5f43_mask.png to /content/mask
# Moved video11_4100_jpg.rf.9db71f864de72a3b7086f0d80b397f3f_mask.png to /content/mask
# Moved GA5_jpg.rf.a39195e568d1f550abca569134d795ee_mask.png to /content/mask
# Moved video2_5270_jpg.rf.c58d70c5baf81802f719f6ee4c8680db_mask.png to /content/mask
# Moved GJ22_jpg.rf.50b3565b29faffd8f37b0b1e53d4f1e3_mask.png to /content/mask
# Moved video3_1750_jpg.rf.d7f3ae52ab7c72d056027d38ee72f5b2_mask.png to /content/mask
# Moved fb939bb1-5257-4879-bafb-539472ffb73d___Maruti-Suzuki-Brezza-Number-Plates-Design-jpg_jpeg.rf.62bcf5efe0f26c1ba5d498fd211e02cc_mask.png to /content/mask
# Moved video4_3290_jpg.rf.192a7656226b889b88b5457f4853cd9b_mask.png to /content/mask
# Moved video2_2870_jpg.rf.e93fccd2e91ee181b604a2aaf67ad408_mask.png to /content/mask
# Moved video3_1440_jpg.rf.30b669364943b9ab29ee071c532af9ec_mask.png to /content/mask
# Moved video2_3740_jpg.rf.bd1c6a09ce6e89700c6c7abf48671012_mask.png to /content/mask
# Moved video5_160_jpg.rf.82b278e19470592f0ed6e4bed9ffd760_mask.png to /content/mask
# Moved video11_4650_jpg.rf.4b181aa463e840659d11a2637bc2dc76_mask.png to /content/mask
# Moved video5_360_jpg.rf.7b98ee592e9696a43e7674c7c65dbb5c_mask.png to /content/mask
# Moved video4_2240_jpg.rf.647d68a3fe681bb4c266503971776b40_mask.png to /content/mask
# Moved video11_3870_jpg.rf.ecd36d9f85d3a93e1abd0cee32f27e9f_mask.png to /content/mask
# Moved video4_3770_jpg.rf.275ca276da3686b80158aa64b9936f63_mask.png to /content/mask
# Moved HP10_jpg.rf.6d7fe5ac47b647224da11bd2566e5eff_mask.png to /content/mask
# Moved HP18_jpg.rf.76ee6eb9f2f2a7e73a8e3f3c84eaa4e1_mask.png to /content/mask
# Moved 20210429_14_22_24_000_M0qQbjq7mhasETXjCQGvnoZxK3a2_F_4160_3120_jpg.rf.ee2420580edec19fdb14f3adc2c43102_mask.png to /content/mask
# Moved video3_1350_jpg.rf.719b3429863a9342a1898a447016f808_mask.png to /content/mask
# Moved video2_380_jpg.rf.02570e88c81221c5db0efc01e6283bba_mask.png to /content/mask
# Moved video11_3920_jpg.rf.edb280ad69c02dfaab5e41fccba3123d_mask.png to /content/mask
# Moved video11_2790_jpg.rf.bba7ff0fb82cdba5a9f91504a139b480_mask.png to /content/mask
# Moved video2_2870_jpg.rf.43b01de21b54b6d152bd8bcaf52483de_mask.png to /content/mask
# Moved video2_4780_jpg.rf.ee7eced92367110281385ee7d503cebc_mask.png to /content/mask
# Moved video3_640_jpg.rf.751ac9ac4c4abc64e32de05b78dec21b_mask.png to /content/mask
# Moved video11_790_jpg.rf.a26368161bf8d6d2264aae622e5f808b_mask.png to /content/mask
# Moved HP12_jpg.rf.1646906727029286a843aa03ce7721df_mask.png to /content/mask
# Moved JH11_jpg.rf.8b83cc76545e41bcef3ae4c758723e5e_mask.png to /content/mask
# Moved video5_380_jpg.rf.5c6f36faae8821fdd219af413c7df06c_mask.png to /content/mask
# Moved video5_180_jpg.rf.a2c73bac7c5b582a2eebb68580160d98_mask.png to /content/mask
# Moved video4_2340_jpg.rf.cade29fbb7df3d921f688dd696c4d931_mask.png to /content/mask
# Moved video11_4720_jpg.rf.d9cd930d10392564a043180c5b407b68_mask.png to /content/mask
# Moved GJ1_jpg.rf.ca52bf30f91c953db860ee1d7232a6e9_mask.png to /content/mask
# Moved video11_800_jpg.rf.14c2a33465b1f79c9e321044ecb3e40f_mask.png to /content/mask
# Moved video4_2800_jpg.rf.b712698069c886af3fc5a111f3e49c52_mask.png to /content/mask
# Moved video5_370_jpg.rf.6efc8b979dfc994428c102378c1496ed_mask.png to /content/mask
# Moved video11_4770_jpg.rf.0722eca5f6e6f96d9c5a50db883489c6_mask.png to /content/mask
# Moved video3_1800_jpg.rf.a96ce0c1e430696320133c08ad306163_mask.png to /content/mask
# Moved video3_550_jpg.rf.5c681a175dc21ee618466e5862bf9867_mask.png to /content/mask
# Moved video3_590_jpg.rf.ae892090a6fc69d3ce4a9ac0f9c281a6_mask.png to /content/mask
# Moved video2_300_jpg.rf.1b81edbe705d22b09c54fa0b9c5e7255_mask.png to /content/mask
# Moved 0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740-jpg_jpeg.rf.38ff3d55fe0ff458f77f962af5c7fd43_mask.png to /content/mask
# Moved video3_580_jpg.rf.985f27084689bbb46242ec3d24863156_mask.png to /content/mask
# Moved 07f6d77a-652e-4885-8520-6d405d2f712f___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_840539077_1_1080x720_nissan-terrano-xl-d-thp-110-ps-2016-diesel-_jpg.rf.618eecd5e2948eba32a064d35a9fd56c_mask.png to /content/mask
# Moved video11_4750_jpg.rf.985d396fb0edf929c4db607cc9cc44ee_mask.png to /content/mask
# Moved video4_2390_jpg.rf.3134c6b7164c55f789dac352ec4fb8ba_mask.png to /content/mask
# Moved 074d85b8-42ec-4d17-9b8e-9e51ae060243___hqdefault-jpg_jpeg.rf.976e40cfd0028b9c93b897fd015fde00_mask.png to /content/mask
# Moved DN5_jpg.rf.113be274c433cd90dfb2be9ec348af4d_mask.png to /content/mask
# Moved video2_440_jpg.rf.47aa1d569d456afb947e375e0d9c28d9_mask.png to /content/mask
# Moved DN7_jpg.rf.9b99fc7511b3e94bf982b6095579f8a2_mask.png to /content/mask
# Moved video4_2380_jpg.rf.74dbdc30fa7b9c1008dceabedbc1e0ea_mask.png to /content/mask
# Moved e1d7921f-5e58-46c7-b4f9-9fd4585508f1___IMG_9072-jpg_jpeg.rf.914910d314b290f7f983b6b27ffd1d9c_mask.png to /content/mask
# Moved video2_4520_jpg.rf.06c22bf8244924e6625cf58d6efebf8f_mask.png to /content/mask
# Moved video5_490_jpg.rf.691bebd40424dd2330bf2e982c0fe766_mask.png to /content/mask
# Moved video3_310_jpg.rf.f1fa827db82dc9230ba83db384f99c62_mask.png to /content/mask
# Moved video11_2660_jpg.rf.52b79d05050c2bc017045ca5ed98509a_mask.png to /content/mask
# Moved video11_4670_jpg.rf.1f4ccddc94c71b89d0074aa82f116c14_mask.png to /content/mask
# Moved video3_1890_jpg.rf.757e933df9b68ff1cdf183af77a8d236_mask.png to /content/mask
# Moved GJ8_jpg.rf.70a6df977a38029f0b7c0bbd2b2d00c2_mask.png to /content/mask
# Moved video5_190_jpg.rf.684f895efaa943b121182590dbe0ea57_mask.png to /content/mask
# Moved video3_1930_jpg.rf.91849138fe0169b3b40a43a71d7cacc5_mask.png to /content/mask
# Moved video3_1100_jpg.rf.e7aab9493ef03825f2884963b526dcad_mask.png to /content/mask
# Moved video4_2590_jpg.rf.ab61ad1a791d93a57ecc169429843a38_mask.png to /content/mask
# Moved GA11_jpg.rf.d68a89e9083fbd59b65fbb92028af2bb_mask.png to /content/mask
# Moved video12_110_jpg.rf.8eeb58fabca507f34c8656d30ad17c48_mask.png to /content/mask
# Moved video11_3250_jpg.rf.e47a2d9c976ddacad150639323bdf42f_mask.png to /content/mask
# Moved video11_2720_jpg.rf.17a988d463e84ab4f73f558ef0ce05ef_mask.png to /content/mask
# Moved video3_1700_jpg.rf.39633777521ff8f88931eb75fb61f7af_mask.png to /content/mask
# Moved video2_4870_jpg.rf.165f44c96c21ae95aba1ce31b8aa2772_mask.png to /content/mask
# Moved DL9_jpg.rf.444eb9a36b7e518b42f2e0967767eb74_mask.png to /content/mask
# Moved video2_460_jpg.rf.73dc27e9617120c92e1460c34f755891_mask.png to /content/mask
# Moved HR14_jpg.rf.e4e12bf122d0dcf4299e8f003cf85db7_mask.png to /content/mask
# Moved DL35_jpg.rf.584c953a8d7a4be78b357b798181c2b6_mask.png to /content/mask
# Moved f7ba7a93-e8d7-4253-b327-d87e3f2bb747___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_2013-Nissan-Terrano-Rear_jpg.rf.3e06ee00154f8945b4abcc5558f1eac0_mask.png to /content/mask
# Moved e663fa35-ce3c-401d-8451-30edd236b3e4___maxresdefault2-jpg_jpeg.rf.435ad9ab3d9d9fb48a7ae5805264f686_mask.png to /content/mask
# Moved video4_2820_jpg.rf.5b42daeee789bd6de0cd0b97738b6608_mask.png to /content/mask
# Moved video2_1590_jpg.rf.423c8ff2618bd48e901a000d348787d5_mask.png to /content/mask
# Moved video2_450_jpg.rf.cd29b3b58f2f4f4f4628b96e189a25eb_mask.png to /content/mask
# Moved video11_4020_jpg.rf.267ff84caac822d9df934ab34f1c156f_mask.png to /content/mask
# Moved video2_1510_jpg.rf.1ad39d96a645f0d5d9141d47b7da50d1_mask.png to /content/mask
# Moved e1d7921f-5e58-46c7-b4f9-9fd4585508f1___IMG_9072-jpg_jpeg.rf.7f8ad11c6481368689bcf1bf60bbc36c_mask.png to /content/mask
# Moved GJ18_jpg.rf.e2a2ce0ca1943779d57826bde294b762_mask.png to /content/mask
# Moved video11_4460_jpg.rf.2a3780f87ba139c96beae08702f91b68_mask.png to /content/mask
# Moved video6_1030_jpg.rf.c49e320f7a01f1572b4bebf85ffa41dd_mask.png to /content/mask
# Moved video4_2580_jpg.rf.d336caea6ca9cefef24d5cae11ab006b_mask.png to /content/mask
# Moved video4_2620_jpg.rf.d70ff2643f5d396ad4a9cbaab1356bfd_mask.png to /content/mask
# Moved video3_1950_jpg.rf.feddacf1458fee1a2dcafd4a61283211_mask.png to /content/mask
# Moved video2_3730_jpg.rf.ff485e1a5b09340fc83294083e7feeca_mask.png to /content/mask
# Moved video11_410_jpg.rf.c3c7433b75389c6c64238b3ddda5b93b_mask.png to /content/mask
# Moved video5_160_jpg.rf.6d761368e5e0fa65da398cb350dda56a_mask.png to /content/mask
# Moved DN4_jpg.rf.470bfc26e230b0a9998dbdb56879391e_mask.png to /content/mask
# Moved video11_3680_jpg.rf.a55a7a37b5d12daa1fa8631ac12d1ccd_mask.png to /content/mask
# Moved video4_2800_jpg.rf.0f18ddaec9ebe6db65f1610dc87095b2_mask.png to /content/mask
# Moved 20210429_11_49_33_000_fIZoRQmuZyVkc7oDgq1fjezTvCu1_F_4160_3120_jpg.rf.b3b846bd89e175fa37ca24ae828aa388_mask.png to /content/mask
# Moved video12_80_jpg.rf.89919f971fb2247277977bf32c282ffd_mask.png to /content/mask
# Moved HR9_jpg.rf.eff15729f956365a3f33f8a68a19c3cf_mask.png to /content/mask
# Moved video2_2210_jpg.rf.87f5618b74f864338c6be9c223401178_mask.png to /content/mask
# Moved video3_1880_jpg.rf.4a553a0709c40c1f1525bc7bd615178c_mask.png to /content/mask
# Moved video5_150_jpg.rf.2edd4f6fee528600d2da95d08cc71ac9_mask.png to /content/mask
# Moved video2_2230_jpg.rf.6241e1492197587b4d5fa51034274db4_mask.png to /content/mask
# Moved video3_470_jpg.rf.22eb7574aaa6778c72627a45f609c1d2_mask.png to /content/mask
# Moved video4_2120_jpg.rf.d277d616603f4639c33138c74c5aa9c2_mask.png to /content/mask
# Moved video11_4730_jpg.rf.72b45d14694ed571337a41be72a443e9_mask.png to /content/mask
# Moved fbb2b3ed-4db1-4d4c-8d4d-4b80b02bfd2a___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_01640f5edbbfb564a9ab6486b31d1554_large_jpg.rf.4d20e5b55c6d11feb0cfcdcf70f9e0de_mask.png to /content/mask
# Moved 20210430_18_29_21_000_XLVFIqldM7Nsyyaj8HLtbWkQQ7r2_T_1856_4000_jpg.rf.fd5484b90bb1b0347e30950a7a3d0c54_mask.png to /content/mask
# Moved video4_2490_jpg.rf.381bcabaf5ebef64a257e3a5ce2e5b03_mask.png to /content/mask
# Moved video4_2720_jpg.rf.931008da043389aadc0ce66a90a9f26b_mask.png to /content/mask
# Moved video2_410_jpg.rf.dddd2d1b4305e44d0f9929a768ca2587_mask.png to /content/mask
# Moved GA6_jpg.rf.b5e6a13f2d3ff5ce3da779718935e188_mask.png to /content/mask
# Moved f5bbb8da-dddd-47ae-a46c-15492f9cf752___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_10187746544_0c0822790e_jpg.rf.03c90cfe6a507b94241231917f06a8d4_mask.png to /content/mask

# %%
from keras.utils import normalize
import os
import glob
import cv2
import numpy as np
from matplotlib import pyplot as plt


#Resizing images, if needed
SIZE_X = 416
SIZE_Y = 416
n_classes=2 #Number of classes for segmentation

#Capture training image info as a list
train_images = []

for directory_path in glob.glob("/content/licence_plate_segmentation_india-1/train/"):
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        img = cv2.imread(img_path, 0)
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        train_images.append(img)


#Convert list to array for machine learning processing
train_images = np.array(train_images)

#Capture mask/label info as a list
train_masks = []
for directory_path in glob.glob("/content/mask"):
    for mask_path in glob.glob(os.path.join(directory_path, "*.png")):
        mask = cv2.imread(mask_path, 0)
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X), interpolation = cv2.INTER_NEAREST)  #Otherwise ground truth changes due to interpolation
        train_masks.append(mask)

#Convert list to array for machine learning processing
train_masks = np.array(train_masks)

# %%
import random
img_number = random.randint(0, len(train_images)-1)
img = train_images[img_number]
mask = train_masks[img_number]


plt.figure(figsize=(12, 8))
plt.subplot(221)
plt.title('Image')
plt.imshow(img)
plt.subplot(222)
plt.title('Mask')
plt.imshow(mask)
plt.show()

# %%
train_masks.shape
train_images.shape
# Out:
# (1761, 416, 416)

# %% [markdown]
# # this is not windows

# %%
import glob
import cv2
image_names = glob.glob("/content/licence_plate_segmentation_india-1/train/*.jpg")
image_names.sort()
image_names = image_names[0:500]

# %%
print(image_names)
# Out:
# ['/content/licence_plate_segmentation_india-1/train/0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740-jpg_jpeg.rf.11afa47f3436878ec0b94dae645fd478.jpg', '/content/licence_plate_segmentation_india-1/train/0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740-jpg_jpeg.rf.14b7bec636d5c9057b2c1000405b5d9d.jpg', '/content/licence_plate_segmentation_india-1/train/0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740-jpg_jpeg.rf.38ff3d55fe0ff458f77f962af5c7fd43.jpg', '/content/licence_plate_segmentation_india-1/train/00b42b2c-f193-4863-b92c-0245cbc816da___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-Petrol-Review-Images-Black-Front-Angle_jpg.rf.33f2e9dcb226b5457fd800eb1718dd7a.jpg', '/content/licence_plate_segmentation_india-1/train/00b42b2c-f193-4863-b92c-0245cbc816da___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-Petrol-Review-Images-Black-Front-Angle_jpg.rf.9b50668d5b266cd39900e58e288265e9.jpg', '/content/licence_plate_segmentation_india-1/train/00b42b2c-f193-4863-b92c-0245cbc816da___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-Petrol-Review-Images-Black-Front-Angle_jpg.rf.d80c83efdcfd2dc637769a5af7ad9724.jpg', '/content/licence_plate_segmentation_india-1/train/03273806-bb1e-48da-8c8b-a0133a90197a___2014-Skoda-Yeti-Test-Drive-jpg_jpeg.rf.0de016f505d2d9d9d3128ad75b97f281.jpg', '/content/licence_plate_segmentation_india-1/train/03273806-bb1e-48da-8c8b-a0133a90197a___2014-Skoda-Yeti-Test-Drive-jpg_jpeg.rf.69c871529cbe7db7aa6e42aeddb82a65.jpg', '/content/licence_plate_segmentation_india-1/train/03273806-bb1e-48da-8c8b-a0133a90197a___2014-Skoda-Yeti-Test-Drive-jpg_jpeg.rf.832ccca386d3b35a88d102bf5b0f5409.jpg', '/content/licence_plate_segmentation_india-1/train/0369b20e-b432-4409-90f9-2420877aa386___8151536c79159a1557421da5f27f9f0e-jpg_jpeg.rf.011020e0a341cb5cb213d29a1f537842.jpg', '/content/licence_plate_segmentation_india-1/train/0369b20e-b432-4409-90f9-2420877aa386___8151536c79159a1557421da5f27f9f0e-jpg_jpeg.rf.a3dbd14f66598413a32bfe4ae5180817.jpg', '/content/licence_plate_segmentation_india-1/train/0369b20e-b432-4409-90f9-2420877aa386___8151536c79159a1557421da5f27f9f0e-jpg_jpeg.rf.f3bb388480ca094bf4beef332b587ea3.jpg', '/content/licence_plate_segmentation_india-1/train/07064c2c-2aa3-4419-91a4-92916de8e54c___mahindra-scorpio-old-car-500x500-jpg_jpeg.rf.8cc800ae46ca45a098ba5debfcbf5949.jpg', '/content/licence_plate_segmentation_india-1/train/07064c2c-2aa3-4419-91a4-92916de8e54c___mahindra-scorpio-old-car-500x500-jpg_jpeg.rf.d04d263c4a3e76daa25ab5ca7dd8ddc5.jpg', '/content/licence_plate_segmentation_india-1/train/07064c2c-2aa3-4419-91a4-92916de8e54c___mahindra-scorpio-old-car-500x500-jpg_jpeg.rf.e7e7b8ac87c28fb1c47cab97648cc1d2.jpg', '/content/licence_plate_segmentation_india-1/train/074d85b8-42ec-4d17-9b8e-9e51ae060243___hqdefault-jpg_jpeg.rf.49f163c02bfe037c72162fb2c1bf3f0f.jpg', '/content/licence_plate_segmentation_india-1/train/074d85b8-42ec-4d17-9b8e-9e51ae060243___hqdefault-jpg_jpeg.rf.71bbd052209912fdc84518d2f185a78f.jpg', '/content/licence_plate_segmentation_india-1/train/074d85b8-42ec-4d17-9b8e-9e51ae060243___hqdefault-jpg_jpeg.rf.976e40cfd0028b9c93b897fd015fde00.jpg', '/content/licence_plate_segmentation_india-1/train/07aaab79-71ee-4ea3-a9e6-640191183947___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_1208484d1392541449-nissan-terrano-official-review-img_20140215_181708_jpg.rf.6d1f796eceb3a8ae75d33df1cfd77571.jpg', '/content/licence_plate_segmentation_india-1/train/07aaab79-71ee-4ea3-a9e6-640191183947___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_1208484d1392541449-nissan-terrano-official-review-img_20140215_181708_jpg.rf.8e48ebfa907377ea3e2e27bc6eacd790.jpg', '/content/licence_plate_segmentation_india-1/train/07aaab79-71ee-4ea3-a9e6-640191183947___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_1208484d1392541449-nissan-terrano-official-review-img_20140215_181708_jpg.rf.bf3ca28b840cb221904ecc8ce046736f.jpg', '/content/licence_plate_segmentation_india-1/train/07bd977e-d578-49a2-b345-7cee5a4db6bf___new ...

# %%
#images = [cv2.imread(image, 1) for image in image_names]
#image_dataset = np.array(images)

# %%
# Initialize an empty list to store resized images
resized_images = []

# Define the target size (416x416 pixels)
target_size = (416, 416)

# Loop through the list of image file paths
for image_path in image_names:
    # Read the image using OpenCV
    image = cv2.imread(image_path, 1)  # 1 for loading color image

    # Check if the image was successfully loaded
    if image is not None:
        # Resize the image to the target size
        resized_image = cv2.resize(image, target_size)

        # Append the resized image to the list
        resized_images.append(resized_image)

# Convert the list of resized images to a NumPy array
image_dataset = np.array(resized_images)

# %%
mask_names = glob.glob("/content/mask/*.png")
mask_names.sort()
mask_names = mask_names[0:500]

# %%
print(mask_names)
# Out:
# ['/content/mask/0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740-jpg_jpeg.rf.11afa47f3436878ec0b94dae645fd478_mask.png', '/content/mask/0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740-jpg_jpeg.rf.14b7bec636d5c9057b2c1000405b5d9d_mask.png', '/content/mask/0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740-jpg_jpeg.rf.38ff3d55fe0ff458f77f962af5c7fd43_mask.png', '/content/mask/00b42b2c-f193-4863-b92c-0245cbc816da___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-Petrol-Review-Images-Black-Front-Angle_jpg.rf.33f2e9dcb226b5457fd800eb1718dd7a_mask.png', '/content/mask/00b42b2c-f193-4863-b92c-0245cbc816da___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-Petrol-Review-Images-Black-Front-Angle_jpg.rf.9b50668d5b266cd39900e58e288265e9_mask.png', '/content/mask/00b42b2c-f193-4863-b92c-0245cbc816da___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-Petrol-Review-Images-Black-Front-Angle_jpg.rf.d80c83efdcfd2dc637769a5af7ad9724_mask.png', '/content/mask/03273806-bb1e-48da-8c8b-a0133a90197a___2014-Skoda-Yeti-Test-Drive-jpg_jpeg.rf.0de016f505d2d9d9d3128ad75b97f281_mask.png', '/content/mask/03273806-bb1e-48da-8c8b-a0133a90197a___2014-Skoda-Yeti-Test-Drive-jpg_jpeg.rf.69c871529cbe7db7aa6e42aeddb82a65_mask.png', '/content/mask/03273806-bb1e-48da-8c8b-a0133a90197a___2014-Skoda-Yeti-Test-Drive-jpg_jpeg.rf.832ccca386d3b35a88d102bf5b0f5409_mask.png', '/content/mask/0369b20e-b432-4409-90f9-2420877aa386___8151536c79159a1557421da5f27f9f0e-jpg_jpeg.rf.011020e0a341cb5cb213d29a1f537842_mask.png', '/content/mask/0369b20e-b432-4409-90f9-2420877aa386___8151536c79159a1557421da5f27f9f0e-jpg_jpeg.rf.a3dbd14f66598413a32bfe4ae5180817_mask.png', '/content/mask/0369b20e-b432-4409-90f9-2420877aa386___8151536c79159a1557421da5f27f9f0e-jpg_jpeg.rf.f3bb388480ca094bf4beef332b587ea3_mask.png', '/content/mask/07064c2c-2aa3-4419-91a4-92916de8e54c___mahindra-scorpio-old-car-500x500-jpg_jpeg.rf.8cc800ae46ca45a098ba5debfcbf5949_mask.png', '/content/mask/07064c2c-2aa3-4419-91a4-92916de8e54c___mahindra-scorpio-old-car-500x500-jpg_jpeg.rf.d04d263c4a3e76daa25ab5ca7dd8ddc5_mask.png', '/content/mask/07064c2c-2aa3-4419-91a4-92916de8e54c___mahindra-scorpio-old-car-500x500-jpg_jpeg.rf.e7e7b8ac87c28fb1c47cab97648cc1d2_mask.png', '/content/mask/074d85b8-42ec-4d17-9b8e-9e51ae060243___hqdefault-jpg_jpeg.rf.49f163c02bfe037c72162fb2c1bf3f0f_mask.png', '/content/mask/074d85b8-42ec-4d17-9b8e-9e51ae060243___hqdefault-jpg_jpeg.rf.71bbd052209912fdc84518d2f185a78f_mask.png', '/content/mask/074d85b8-42ec-4d17-9b8e-9e51ae060243___hqdefault-jpg_jpeg.rf.976e40cfd0028b9c93b897fd015fde00_mask.png', '/content/mask/07aaab79-71ee-4ea3-a9e6-640191183947___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_1208484d1392541449-nissan-terrano-official-review-img_20140215_181708_jpg.rf.6d1f796eceb3a8ae75d33df1cfd77571_mask.png', '/content/mask/07aaab79-71ee-4ea3-a9e6-640191183947___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_1208484d1392541449-nissan-terrano-official-review-img_20140215_181708_jpg.rf.8e48ebfa907377ea3e2e27bc6eacd790_mask.png', '/content/mask/07aaab79-71ee-4ea3-a9e6-640191183947___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_1208484d1392541449-nissan-terrano-official-review-img_20140215_181708_jpg.rf.bf3ca28b840cb221904ecc8ce046736f_mask.png', '/content/mask/07bd977e-d578-49a2-b345-7cee5a4db6bf___new_1031520d1356604430-skoda-rapid-joins-family-edit-sold-wp_000281-jpg_jpeg.rf.07be7c00aacd016ab9e296f11ae8da1f_mask.png', '/content/mask/07bd977e-d578-49a2-b345-7cee5a4db6bf___new_1031520d1356604430-skoda-rapid-joins-family-edit-sold-wp_000281-jpg_jpeg.rf.50df28460897de02ae1e5a171a2e4778_mask.png', '/content/mask/07bd977e-d578-49a2-b345-7cee5a4db6bf___new_1031520d1356604430-skoda-rapid-joins-family-edit-sold-wp_000281-jpg_jpeg.rf.c53b3ec4d824b9c828f20d9c3b0ae98f_mask.png', '/content/mask/07e787a7-6cc3-482c-9ce5-f0ce115b47f1___new_VW-Polo-GT-TSI-badges-on-the-boot-lid-jpg_jpeg.rf.71a7228594444b0d06420f4424f41eff_mask.png', '/content/mask/07e787a7-6cc3-482c-9ce5-f0ce115b47f1___new_ ...

# %%
#masks = [cv2.imread(mask,0) for mask in mask_names]
#mask_dataset = np.array(masks)

# %%
# Initialize an empty list to store resized mask images
resized_masks = []

# Define the target size (e.g., 416x416 pixels)
target_size = (416, 416)

# Loop through the list of mask image file paths
for mask_path in mask_names:
    # Read the mask image using OpenCV
    mask_image = cv2.imread(mask_path, 0)  # 0 for loading grayscale image

    # Check if the mask image was successfully loaded
    if mask_image is not None:
        # Resize the mask image to the target size
        resized_mask = cv2.resize(mask_image, target_size)

        # Append the resized mask image to the list
        resized_masks.append(resized_mask)

# Convert the list of resized mask images to a NumPy array
mask_dataset = np.array(resized_masks)

# %%
image_dataset.shape
mask_dataset.shape
# Out:
# (500, 416, 416)

# %%
import numpy as np
np.unique(mask_dataset)
# Out:
# array([0, 1], dtype=uint8)

# %%
# Sanity check...
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number])
plt.subplot(122)
plt.imshow(mask_dataset[image_number])
plt.show()

# %%
import random
img_number = random.randint(0, len(image_dataset)-1)
img = image_dataset[img_number]
mask = mask_dataset[img_number]
plt.figure(figsize=(12, 8))
plt.subplot(221)
plt.title('Image')
plt.imshow(img)
plt.subplot(222)
plt.title('Mask')
plt.imshow(mask)
plt.show()

# %%
###############################################
#Encode labels... but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = mask_dataset.shape
train_masks_reshaped = mask_dataset.reshape(-1,1)
train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)

np.unique(train_masks_encoded_original_shape)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# array([0, 1])

# %%
#############################################

#################################################
train_images = np.expand_dims(image_dataset, axis=3)
train_images = normalize(image_dataset, axis=1)

train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

#Create a subset of data for quick testing
#Picking 10% for testing and remaining for training
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, train_masks_input, test_size = 0.10, random_state = 0)


print("Class values in the dataset are ... ", np.unique(y_train.ravel()))


print(n)
print(h)
print(w)
# Out:
# Class values in the dataset are ...  [0 1]
# 500
# 416
# 416

# %%
from keras.utils import to_categorical

# Convert class labels to categorical representation
train_masks_cat = to_categorical(y_train, num_classes=n_classes)
y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))

test_masks_cat = to_categorical(y_test, num_classes=n_classes)
y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))

# %%
import tensorflow as tf

IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]


print(IMG_HEIGHT)
print(IMG_WIDTH)
print(IMG_CHANNELS)




def get_model():
    return multi_unet_model1(n_classes=n_classes, IMG_H=IMG_HEIGHT, IMG_W=IMG_WIDTH, IMG_CHANNELS=IMG_CHANNELS)

model = get_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

#If starting with pre-trained weights.
#model.load_weights('???.hdf5')
#Modelcheckpoint
checkpointer = tf.keras.callbacks.ModelCheckpoint('model_for_nuclei.h5', verbose=1, save_best_only=True)

callbacks = [tf.keras.callbacks.TensorBoard(log_dir='logs')]



history = model.fit(X_train, y_train_cat,
                    batch_size = 8,
                    verbose=1,
                    epochs=100,
                    validation_data=(X_test, y_test_cat),
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-096d10868ae2> in <cell line: 3>()
#       1 import tensorflow as tf
#       2
# ----> 3 IMG_HEIGHT = X_train.shape[1]
#       4 IMG_WIDTH  = X_train.shape[2]
#       5 IMG_CHANNELS = X_train.shape[3]
#
# NameError: name 'X_train' is not defined

# %%
model.save('test.hdf5')
#model.save('sandstone_50_epochs_catXentropy_acc_with_weights.hdf5')
############################################################
#Evaluate the model
	# evaluate model
_, acc = model.evaluate(X_test, y_test_cat)
print("Accuracy is = ", (acc * 100.0), "%")


###
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Replace 'acc' with 'accuracy' for training and validation accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 2/2 [==============================] - 11s 4s/step - loss: 0.0225 - accuracy: 0.9955
# Accuracy is =  99.54845905303955 %

# %%
from keras.models import load_model
import tensorflow as tf
# Save the model in the SavedModel format
tf.saved_model.save(model, 'saved_model')

# Load the saved model
loaded_model = tf.saved_model.load('saved_model')


#model.save('sandstone_50_epochs_catXentropy_acc_with_weights.hdf5')
############################################################
#Evaluate the model
	# evaluate model
_, acc = model.evaluate(X_test, y_test_cat)
print("Accuracy is = ", (acc * 100.0), "%")


###
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Replace 'acc' with 'accuracy' for training and validation accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 115ms/step - loss: 0.3432 - accuracy: 0.8457
# Accuracy is =  84.56748127937317 %

# %%
# !pip install pydot
# !sudo apt-get install graphviz
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

# Load the model
model = load_model('/content/test.hdf5')  # Load your model here

# Plot the model architecture
plot_model(model, to_file='model_architecture.png', show_shapes=True)
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot) (2.4.7)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6).
# 0 upgraded, 0 newly installed, 0 to remove and 17 not upgraded.

# %%
##################################
model = get_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.load_weights('/content/test.hdf5')
#model.load_weights('sandstone_50_epochs_catXentropy_acc_with_weights.hdf5')
checkpointer = tf.keras.callbacks.ModelCheckpoint('model_for_nuclei.h5', verbose=1, save_best_only=True)

callbacks = [tf.keras.callbacks.TensorBoard(log_dir='logs')]




history = model.fit(X_train, y_train_cat,
                    batch_size = 8,
                    verbose=1,
                    epochs=200,
                    validation_data=(X_test, y_test_cat),
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    shuffle=False)

#IOU
y_pred=model.predict(X_test)
y_pred_argmax=np.argmax(y_pred, axis=3)

##################################################

#Using built in keras function
from keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:,:,:,0], y_pred_argmax)
print("Mean IoU =", IOU_keras.result().numpy())


# Calculate IoU for each class...
values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)

class1_IoU = values[0, 0] / (np.sum(values[0, :]) + np.sum(values[:, 0]) - values[0, 0])
class2_IoU = values[1, 1] / (np.sum(values[1, :]) + np.sum(values[:, 1]) - values[1, 1])


print("IoU for class1 is: ", class1_IoU)
print("IoU for class2 is: ", class2_IoU)


plt.imshow(train_images[0, :,:,0], cmap='gray')
plt.imshow(train_masks[0], cmap='gray')
#######################################################################
# Out:
# Epoch 1/200
# 57/57 [==============================] - 25s 288ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0239 - val_accuracy: 0.9950
# Epoch 2/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0104 - accuracy: 0.9962 - val_loss: 0.0221 - val_accuracy: 0.9941
# Epoch 3/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0087 - accuracy: 0.9967 - val_loss: 0.0162 - val_accuracy: 0.9955
# Epoch 4/200
# 57/57 [==============================] - 14s 245ms/step - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.0257 - val_accuracy: 0.9955
# Epoch 5/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0248 - val_accuracy: 0.9936
# Epoch 6/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0072 - accuracy: 0.9971 - val_loss: 0.0224 - val_accuracy: 0.9954
# Epoch 7/200
# 57/57 [==============================] - 14s 253ms/step - loss: 0.0053 - accuracy: 0.9978 - val_loss: 0.0255 - val_accuracy: 0.9958
# Epoch 8/200
# 57/57 [==============================] - 14s 249ms/step - loss: 0.0064 - accuracy: 0.9975 - val_loss: 0.0236 - val_accuracy: 0.9954
# Epoch 9/200
# 57/57 [==============================] - 14s 253ms/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.0222 - val_accuracy: 0.9957
# Epoch 10/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0051 - accuracy: 0.9979 - val_loss: 0.0280 - val_accuracy: 0.9957
# Epoch 11/200
# 57/57 [==============================] - 14s 253ms/step - loss: 0.0055 - accuracy: 0.9978 - val_loss: 0.0346 - val_accuracy: 0.9934
# Epoch 12/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.0378 - val_accuracy: 0.9938
# Epoch 13/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0270 - accuracy: 0.9940 - val_loss: 0.0420 - val_accuracy: 0.9923
# Epoch 14/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0318 - accuracy: 0.9911 - val_loss: 0.0256 - val_accuracy: 0.9937
# Epoch 15/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0154 - accuracy: 0.9947 - val_loss: 0.0190 - val_accuracy: 0.9946
# Epoch 16/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0108 - accuracy: 0.9960 - val_loss: 0.0240 - val_accuracy: 0.9950
# Epoch 17/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0081 - accuracy: 0.9969 - val_loss: 0.0218 - val_accuracy: 0.9954
# Epoch 18/200
# 57/57 [==============================] - 14s 253ms/step - loss: 0.0069 - accuracy: 0.9973 - val_loss: 0.0197 - val_accuracy: 0.9955
# Epoch 19/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0056 - accuracy: 0.9977 - val_loss: 0.0252 - val_accuracy: 0.9955
# Epoch 20/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0051 - accuracy: 0.9979 - val_loss: 0.0272 - val_accuracy: 0.9957
# Epoch 21/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0049 - accuracy: 0.9979 - val_loss: 0.0277 - val_accuracy: 0.9955
# Epoch 22/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0047 - accuracy: 0.9980 - val_loss: 0.0251 - val_accuracy: 0.9958
# Epoch 23/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0044 - accuracy: 0.9981 - val_loss: 0.0295 - val_accuracy: 0.9955
# Epoch 24/200
# 57/57 [==============================] - 14s 253ms/step - loss: 0.0043 - accuracy: 0.9982 - val_loss: 0.0288 - val_accuracy: 0.9957
# Epoch 25/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0348 - val_accuracy: 0.9959
# Epoch 26/200
# 57/57 [==============================] - 14s 253ms/step - loss: 0.0052 - accuracy: 0.9979 - val_loss: 0.0326 - val_accuracy: 0.9955
# Epoch 27/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0042 - accuracy: 0.9982 - val_loss: 0.0318 - val_accuracy: 0.9958
# Epoch 28/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0260 - val_accuracy: 0.9956
# Epoch 29/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0045 - accuracy: 0.9981 - val_loss: 0.0317 - val_accuracy: 0.9954
# Epoch 30/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0043 - accuracy: 0.9982 - val_loss: 0.0254 - val_accuracy: 0.9958
# Epoch 31/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0040 - accuracy: 0.9983 - val_loss: 0.0266 - val_accuracy: 0.9961
# Epoch 32/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0040 - accuracy: 0.9983 - val_loss: 0.0322 - val_accuracy: 0.9959
# Epoch 33/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.0312 - val_accuracy: 0.9959
# Epoch 34/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0036 - accuracy: 0.9985 - val_loss: 0.0312 - val_accuracy: 0.9956
# Epoch 35/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.0345 - val_accuracy: 0.9958
# Epoch 36/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.0340 - val_accuracy: 0.9958
# Epoch 37/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0310 - val_accuracy: 0.9961
# Epoch 38/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.0290 - val_accuracy: 0.9960
# Epoch 39/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.0303 - val_accuracy: 0.9959
# Epoch 40/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.0298 - val_accuracy: 0.9956
# Epoch 41/200
# 57/57 [==============================] - 14s 253ms/step - loss: 0.0037 - accuracy: 0.9985 - val_loss: 0.0272 - val_accuracy: 0.9959
# Epoch 42/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.0288 - val_accuracy: 0.9960
# Epoch 43/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0266 - val_accuracy: 0.9958
# Epoch 44/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.0346 - val_accuracy: 0.9955
# Epoch 45/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0034 - accuracy: 0.9986 - val_loss: 0.0331 - val_accuracy: 0.9957
# Epoch 46/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.0386 - val_accuracy: 0.9957
# Epoch 47/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.0387 - val_accuracy: 0.9960
# Epoch 48/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0030 - accuracy: 0.9987 - val_loss: 0.0343 - val_accuracy: 0.9961
# Epoch 49/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0030 - accuracy: 0.9987 - val_loss: 0.0313 - val_accuracy: 0.9960
# Epoch 50/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.0339 - val_accuracy: 0.9960
# Epoch 51/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0032 - accuracy: 0.9987 - val_loss: 0.0382 - val_accuracy: 0.9958
# Epoch 52/200
# 57/57 [==============================] - 14s 253ms/step - loss: 0.0035 - accuracy: 0.9986 - val_loss: 0.0267 - val_accuracy: 0.9955
# Epoch 53/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0040 - accuracy: 0.9984 - val_loss: 0.0384 - val_accuracy: 0.9960
# Epoch 54/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.0163 - val_accuracy: 0.9965
# Epoch 55/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0811 - accuracy: 0.9858 - val_loss: 0.0819 - val_accuracy: 0.9851
# Epoch 56/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.1095 - accuracy: 0.9807 - val_loss: 0.1321 - val_accuracy: 0.9851
# Epoch 57/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.1161 - accuracy: 0.9807 - val_loss: 0.0856 - val_accuracy: 0.9851
# Epoch 58/200
# 57/57 [==============================] - 14s 245ms/step - loss: 0.0751 - accuracy: 0.9807 - val_loss: 0.0557 - val_accuracy: 0.9851
# Epoch 59/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0602 - accuracy: 0.9807 - val_loss: 0.0473 - val_accuracy: 0.9851
# Epoch 60/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0557 - accuracy: 0.9807 - val_loss: 0.0498 - val_accuracy: 0.9851
# Epoch 61/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0481 - accuracy: 0.9807 - val_loss: 0.0444 - val_accuracy: 0.9851
# Epoch 62/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0424 - accuracy: 0.9807 - val_loss: 0.0426 - val_accuracy: 0.9851
# Epoch 63/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0378 - accuracy: 0.9807 - val_loss: 0.0411 - val_accuracy: 0.9851
# Epoch 64/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0327 - accuracy: 0.9807 - val_loss: 0.0382 - val_accuracy: 0.9851
# Epoch 65/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0280 - accuracy: 0.9807 - val_loss: 0.0341 - val_accuracy: 0.9851
# Epoch 66/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0237 - accuracy: 0.9807 - val_loss: 0.0320 - val_accuracy: 0.9851
# Epoch 67/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0204 - accuracy: 0.9925 - val_loss: 0.0348 - val_accuracy: 0.9935
# Epoch 68/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0180 - accuracy: 0.9947 - val_loss: 0.0341 - val_accuracy: 0.9935
# Epoch 69/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0165 - accuracy: 0.9951 - val_loss: 0.0285 - val_accuracy: 0.9930
# Epoch 70/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0177 - accuracy: 0.9946 - val_loss: 0.0306 - val_accuracy: 0.9938
# Epoch 71/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0147 - accuracy: 0.9955 - val_loss: 0.0365 - val_accuracy: 0.9941
# Epoch 72/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0134 - accuracy: 0.9959 - val_loss: 0.0338 - val_accuracy: 0.9945
# Epoch 73/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0123 - accuracy: 0.9961 - val_loss: 0.0275 - val_accuracy: 0.9947
# Epoch 74/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0325 - val_accuracy: 0.9947
# Epoch 75/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0348 - val_accuracy: 0.9946
# Epoch 76/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.0408 - val_accuracy: 0.9944
# Epoch 77/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0289 - val_accuracy: 0.9949
# Epoch 78/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0322 - val_accuracy: 0.9955
# Epoch 79/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.0382 - val_accuracy: 0.9955
# Epoch 80/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0405 - val_accuracy: 0.9954
# Epoch 81/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0357 - val_accuracy: 0.9954
# Epoch 82/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.0317 - val_accuracy: 0.9959
# Epoch 83/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.0385 - val_accuracy: 0.9951
# Epoch 84/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0384 - val_accuracy: 0.9950
# Epoch 85/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0348 - val_accuracy: 0.9953
# Epoch 86/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0359 - val_accuracy: 0.9956
# Epoch 87/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0379 - val_accuracy: 0.9953
# Epoch 88/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0421 - val_accuracy: 0.9955
# Epoch 89/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0319 - val_accuracy: 0.9958
# Epoch 90/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0492 - val_accuracy: 0.9954
# Epoch 91/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0488 - val_accuracy: 0.9952
# Epoch 92/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0367 - val_accuracy: 0.9957
# Epoch 93/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.0476 - val_accuracy: 0.9957
# Epoch 94/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0328 - val_accuracy: 0.9957
# Epoch 95/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0497 - val_accuracy: 0.9954
# Epoch 96/200
# 57/57 [==============================] - 14s 248ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0424 - val_accuracy: 0.9956
# Epoch 97/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.0340 - val_accuracy: 0.9957
# Epoch 98/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0184 - val_accuracy: 0.9956
# Epoch 99/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.0328 - val_accuracy: 0.9933
# Epoch 100/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 0.0324 - val_accuracy: 0.9955
# Epoch 101/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0066 - accuracy: 0.9975 - val_loss: 0.0325 - val_accuracy: 0.9954
# Epoch 102/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.
200
# 57/57 [==============================] - 14s 250ms/step - loss: 0.0341 - accuracy: 0.9904 - val_loss: 0.0219 - val_accuracy: 0.9932
# Epoch 148/200
# 57/57 [==============================] - 14s 245ms/step - loss: 0.0333 - accuracy: 0.9907 - val_loss: 0.0214 - val_accuracy: 0.9935
# Epoch 149/200
# 57/57 [==============================] - 14s 250ms/step - loss: 0.0318 - accuracy: 0.9910 - val_loss: 0.0212 - val_accuracy: 0.9936
# Epoch 150/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0308 - accuracy: 0.9913 - val_loss: 0.0204 - val_accuracy: 0.9937
# Epoch 151/200
# 57/57 [==============================] - 14s 250ms/step - loss: 0.0303 - accuracy: 0.9914 - val_loss: 0.0202 - val_accuracy: 0.9938
# Epoch 152/200
# 57/57 [==============================] - 14s 245ms/step - loss: 0.0289 - accuracy: 0.9918 - val_loss: 0.0198 - val_accuracy: 0.9941
# Epoch 153/200
# 57/57 [==============================] - 14s 245ms/step - loss: 0.0286 - accuracy: 0.9919 - val_loss: 0.0192 - val_accuracy: 0.9941
# Epoch 154/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0273 - accuracy: 0.9924 - val_loss: 0.0197 - val_accuracy: 0.9942
# Epoch 155/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0268 - accuracy: 0.9925 - val_loss: 0.0188 - val_accuracy: 0.9942
# Epoch 156/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0261 - accuracy: 0.9927 - val_loss: 0.0178 - val_accuracy: 0.9944
# Epoch 157/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0252 - accuracy: 0.9930 - val_loss: 0.0178 - val_accuracy: 0.9944
# Epoch 158/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0246 - accuracy: 0.9931 - val_loss: 0.0184 - val_accuracy: 0.9943
# Epoch 159/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0236 - accuracy: 0.9933 - val_loss: 0.0172 - val_accuracy: 0.9945
# Epoch 160/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0228 - accuracy: 0.9935 - val_loss: 0.0174 - val_accuracy: 0.9944
# Epoch 161/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0230 - accuracy: 0.9934 - val_loss: 0.0176 - val_accuracy: 0.9943
# Epoch 162/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0222 - accuracy: 0.9936 - val_loss: 0.0175 - val_accuracy: 0.9945
# Epoch 163/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0211 - accuracy: 0.9938 - val_loss: 0.0174 - val_accuracy: 0.9945
# Epoch 164/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0202 - accuracy: 0.9939 - val_loss: 0.0165 - val_accuracy: 0.9947
# Epoch 165/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0192 - accuracy: 0.9941 - val_loss: 0.0167 - val_accuracy: 0.9947
# Epoch 166/200
# 57/57 [==============================] - 14s 245ms/step - loss: 0.0220 - accuracy: 0.9934 - val_loss: 0.0184 - val_accuracy: 0.9945
# Epoch 167/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0192 - accuracy: 0.9939 - val_loss: 0.0189 - val_accuracy: 0.9943
# Epoch 168/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0173 - accuracy: 0.9944 - val_loss: 0.0182 - val_accuracy: 0.9945
# Epoch 169/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0194 - val_accuracy: 0.9943
# Epoch 170/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.0176 - val_accuracy: 0.9943
# Epoch 171/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 0.0189 - val_accuracy: 0.9945
# Epoch 172/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 0.0176 - val_accuracy: 0.9940
# Epoch 173/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0194 - accuracy: 0.9938 - val_loss: 0.0215 - val_accuracy: 0.9936
# Epoch 174/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0179 - accuracy: 0.9940 - val_loss: 0.0178 - val_accuracy: 0.9942
# Epoch 175/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0150 - accuracy: 0.9948 - val_loss: 0.0175 - val_accuracy: 0.9943
# Epoch 176/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0143 - accuracy: 0.9951 - val_loss: 0.0166 - val_accuracy: 0.9945
# Epoch 177/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.0175 - val_accuracy: 0.9940
# Epoch 178/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0127 - accuracy: 0.9956 - val_loss: 0.0155 - val_accuracy: 0.9950
# Epoch 179/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.0208 - val_accuracy: 0.9934
# Epoch 180/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0157 - accuracy: 0.9947 - val_loss: 0.0176 - val_accuracy: 0.9939
# Epoch 181/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.0157 - val_accuracy: 0.9948
# Epoch 182/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.0156 - val_accuracy: 0.9952
# Epoch 183/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.0154 - val_accuracy: 0.9951
# Epoch 184/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.0153 - val_accuracy: 0.9951
# Epoch 185/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.0160 - val_accuracy: 0.9949
# Epoch 186/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0104 - accuracy: 0.9963 - val_loss: 0.0167 - val_accuracy: 0.9945
# Epoch 187/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0104 - accuracy: 0.9963 - val_loss: 0.0173 - val_accuracy: 0.9944
# Epoch 188/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.0180 - val_accuracy: 0.9940
# Epoch 189/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0167 - val_accuracy: 0.9945
# Epoch 190/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0177 - val_accuracy: 0.9941
# Epoch 191/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0237 - val_accuracy: 0.9917
# Epoch 192/200
# 57/57 [==============================] - 14s 251ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.0179 - val_accuracy: 0.9940
# Epoch 193/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0130 - accuracy: 0.9956 - val_loss: 0.0207 - val_accuracy: 0.9928
# Epoch 194/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.0176 - val_accuracy: 0.9943
# Epoch 195/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0155 - val_accuracy: 0.9952
# Epoch 196/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0099 - accuracy: 0.9964 - val_loss: 0.0181 - val_accuracy: 0.9941
# Epoch 197/200
# 57/57 [==============================] - 14s 246ms/step - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.0166 - val_accuracy: 0.9947
# Epoch 198/200
# 57/57 [==============================] - 14s 252ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0162 - val_accuracy: 0.9949
# Epoch 199/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0090 - accuracy: 0.9968 - val_loss: 0.0174 - val_accuracy: 0.9943
# Epoch 200/200
# 57/57 [==============================] - 14s 247ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0154 - val_accuracy: 0.9953
# 2/2 [==============================] - 0s 170ms/step
# Mean IoU = 0.86011076
# IoU for class1 is:  0.995251
# IoU for class2 is:  0.7249705

# %%
import random
import matplotlib.pyplot as plt

# Randomly select a test image
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth = y_test[test_img_number]

# Expand the dimensions to (1, x, y, 3) to represent a single color image
test_img = np.expand_dims(test_img, axis=0)

# Predict using the model
y_pred = model.predict(test_img)
y_pred_argmax = np.argmax(y_pred, axis=3)[0]

# Display the images
plt.figure(figsize=(12, 8))

plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[0], cmap='gray')  # Display the color image
plt.axis('off')

plt.subplot(232)
plt.title('Ground Truth Label')
plt.imshow(ground_truth[:, :, 0], cmap='jet')
plt.axis('off')

plt.subplot(233)
plt.title('Prediction on Test Image')
plt.imshow(y_pred_argmax, cmap='jet')
plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
# Create an RGB version of the predicted mask (assuming class labels)
y_pred_rgb = np.zeros((y_pred_argmax.shape[0], y_pred_argmax.shape[1], 3), dtype=np.uint8)
y_pred_rgb[y_pred_argmax == 0] = [0, 0, 0]         # Class 0 (background)
y_pred_rgb[y_pred_argmax == 1] = [0, 255, 0]       # Class 1 (red)

# Blend the original image with the segmented mask
alpha = 0.6  # Adjust the alpha value for blending
overlay = cv2.addWeighted(test_img[0], alpha, y_pred_rgb, 1 - alpha, 0)

# Display the images
plt.figure(figsize=(12, 8))

plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[0], cmap='gray')  # Display the color image
plt.axis('off')

plt.subplot(232)
plt.title('Ground Truth Label')
plt.imshow(ground_truth[:, :, 0], cmap='jet')
plt.axis('off')

plt.subplot(233)
plt.title('Prediction on Test Image')
plt.imshow(y_pred_argmax, cmap='jet')
plt.axis('off')

plt.subplot(234)
plt.title('Overlay')
plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.show()

# %% [markdown]
# #approach for better training

# %%
#Apply a trained model on large image
# !pip install patchify
from patchify import patchify, unpatchify

large_image = cv2.imread('/content/licence_plate_segmentation_india-1/train/0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740-jpg_jpeg.rf.38ff3d55fe0ff458f77f962af5c7fd43.jpg', 0)
#This will split the image into small images of shape [3,3]
patches = patchify(large_image, (128, 128), step=128)  #Step=256 for 256 patches means no overlap

predicted_patches = []
for i in range(patches.shape[0]):
    for j in range(patches.shape[1]):
        print(i,j)

        single_patch = patches[i,j,:,:]
        single_patch_norm = np.expand_dims(normalize(np.array(single_patch), axis=1),2)
        single_patch_input=np.expand_dims(single_patch_norm, 0)
        # Define the new dimensions (e.g., 416x416)
        new_height = 416
        new_width = 416

        # Resize the image
        single_patch_input = cv2.resize(single_patch_input[0], (new_width, new_height))

        single_patch_prediction = (model.predict(single_patch_input))
        single_patch_predicted_img=np.argmax(single_patch_prediction, axis=3)[0,:,:]

        predicted_patches.append(single_patch_predicted_img)

predicted_patches = np.array(predicted_patches)

predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], 128,128) )

reconstructed_image = unpatchify(predicted_patches_reshaped, large_image.shape)
plt.imshow(reconstructed_image, cmap='gray')
#plt.imsave('data/results/segm.jpg', reconstructed_image, cmap='gray')

plt.hist(reconstructed_image.flatten())  #Threshold everything above 0

# final_prediction = (reconstructed_image > 0.01).astype(np.uint8)
# plt.imshow(final_prediction)

plt.figure(figsize=(8, 8))
plt.subplot(221)
plt.title('Large Image')
plt.imshow(large_image, cmap='gray')
plt.subplot(222)
plt.title('Prediction of large Image')
plt.imshow(reconstructed_image, cmap='jet')
plt.show()
# Out:
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from patchify) (1.23.5)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3
# 0 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-f823a5e783f8> in <cell line: 10>()
#      22         single_patch_input = cv2.resize(single_patch_input[0], (new_width, new_height))
#      23
# ---> 24         single_patch_prediction = (model.predict(single_patch_input))
#      25         single_patch_predicted_img=np.argmax(single_patch_prediction, axis=3)[0,:,:]
#      26
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2341, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2327, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2315, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2283, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 253, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer 'model_3' (type Functional).
#
#     Input 0 of layer "conv2d_57" is incompatible with the layer: expected min_ndim=4, found ndim=2. Full shape received: (32, 416)
#
#     Call arguments received by layer 'model_3' (type Functional):
#       • inputs=tf.Tensor(shape=(32, 416), dtype=float32)
#       • training=False
#       • mask=None

# %%
model.save('test_final_200.hdf5')
# Out:
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.

# %%
def get_model():
    return multi_unet_model1(n_classes=2, IMG_H=416, IMG_W=416, IMG_CHANNELS=3)

# %%
IMG_HEIGHT=416
IMG_WIDTH = 416
target_size = (416,416)

model = get_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.load_weights('/content/drive/MyDrive/Colab Notebooks/test_final_200.hdf5')




# Read the image using OpenCV
resized_images1 = []  # Initialize an empty list to store resized images
image_path1 = "/content/dataset-card.jpg"
image = cv2.imread(image_path1, 1)  # 1 for loading color image

# Check if the image was successfully loaded
if image is not None:
    # Resize the image to the target size
    resized_image = cv2.resize(image, target_size)

    # Append the resized image to the list
    resized_images1.append(resized_image)

# Convert the list of resized images to a NumPy array
test_img = np.array(resized_images1)

# Expand the dimensions to (1, x, y, 3) to represent a single color image
#test_img = np.expand_dims(test_img, axis=0)
print(test_img.shape)
# Predict using the model
y_pred = model.predict(test_img)
y_pred_argmax = np.argmax(y_pred, axis=3)[0]

# Create an RGB version of the predicted mask (assuming class labels)
y_pred_rgb = np.zeros((y_pred_argmax.shape[0], y_pred_argmax.shape[1], 3), dtype=np.uint8)
y_pred_rgb[y_pred_argmax == 0] = [0, 0, 0]         # Class 0 (background)
y_pred_rgb[y_pred_argmax == 1] = [0, 255, 0]       # Class 1 (red)

# Blend the original image with the segmented mask
alpha = 0.6  # Adjust the alpha value for blending
overlay = cv2.addWeighted(test_img[0], alpha, y_pred_rgb, 1 - alpha, 0)

# Display the images
plt.figure(figsize=(12, 8))

plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[0], cmap='gray')  # Display the color image
plt.axis('off')

plt.subplot(233)
plt.title('Prediction on Test Image')
plt.imshow(y_pred_argmax, cmap='jet')
plt.axis('off')

plt.subplot(234)
plt.title('Overlay')
plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.show()
# Out:
# (1, 416, 416, 3)
# 1/1 [==============================] - 11s 11s/step

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
