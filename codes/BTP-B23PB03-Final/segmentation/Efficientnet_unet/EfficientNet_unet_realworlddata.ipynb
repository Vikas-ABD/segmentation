# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Sk1acyabG8ztZRaSNSfR")
project = rf.workspace("objectdetection-hgb5p").project("unet_model")
dataset = project.version(2).download("png-mask-semantic")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.11-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 2.5 MB/s eta 0:00:00
# Collecting certifi==2023.7.22 (from roboflow)
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 8.1 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.2 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.16.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.7 MB/s eta 0:00:00
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.45.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.4)
# Installing collected packages: python-magic, python-dotenv, pyparsing, opencv-python-headless, idna, cycler, chardet, certifi, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.11.17
#     Uninstalling certifi-2023.11.17:
#       Successfully uninstalled certifi-2023.11.17
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 pyparsing-2.4.7 python-dotenv-1.0.0 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.11 supervision-0.16.0
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in unet_model-2 to png-mask-semantic:: 100%|██████████| 152335/152335 [00:05<00:00, 27434.22it/s]
# Extracting Dataset Version Zip to unet_model-2 in png-mask-semantic:: 100%|██████████| 3226/3226 [00:01<00:00, 2124.07it/s]

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="Sk1acyabG8ztZRaSNSfR")
project = rf.workspace().project("unet_model")
model = project.version(2).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# infer on a local image
print(model.predict("/content/5559289292_4919d35313_o-56a3bee25f9b58b7d0d394b6.jpg").json())


# save an image annotated with your predictions
model.predict("/content/5559289292_4919d35313_o-56a3bee25f9b58b7d0d394b6.jpg").save("prediction.jpg")
# Out:
# {'predictions': [{'segmentation_mask': '...', 'class_map': {'0': 'background', '1': 'Road Lane', '2': 'auto', '3': 'bike', '4': 'bus', '5': 'car', '6': 'truck'}, 'image': {'width': 1280, 'height': 853}, 'image_path': '/content/5559289292_4919d35313_o-56a3bee25f9b58b7d0d394b6.jpg', 'prediction_type': 'SemanticSegmentationModel'}], 'image': {'width': '1280', 'height': '853'}}

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.applications import EfficientNetB1

def multi_unet_model2(n_classes=7, IMG_H=416, IMG_W=416, IMG_CHANNELS=3):


    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

    # EfficientNet-B1 model without top layers
    efficientnet_base = EfficientNetB1(weights='imagenet', include_top=False, input_tensor=inputs)
    # Extract the first 50 layers of the EfficientNet-B1 model
    efficientnet_layers = efficientnet_base.layers[:50]
    efficientnet_output = efficientnet_layers[-1].output

    print(efficientnet_output.shape)

    # Upsample to (128, 128, 144)
    x = Conv2DTranspose(144, (2, 2), strides=(2, 2), padding='same', activation='relu')(efficientnet_output)
    print(x.shape)
    # Upsample to (256, 256, 72)
    x = Conv2DTranspose(72, (2, 2), strides=(2, 2), padding='same', activation='relu')(x)
    print(x.shape)
    # Further upsample to (256, 256, 3)
    output_tensor = Conv2DTranspose(3, (2, 2), strides=(1, 1), padding='same', activation='relu')(x)
    print(output_tensor.shape)

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(output_tensor)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)


    #Expansive path
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)



    model = Model(inputs=[inputs], outputs=[outputs])

    # Compile the model
    #model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
# !mkdir mask

# %%
import os
import shutil

# Replace these paths with your actual source and destination folder paths
source_folder = '/content/unet_model-2/train/'
destination_folder = '/content/mask'

# Create the destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Iterate through the files in the source folder
for filename in os.listdir(source_folder):
    if filename.endswith('_mask.png'):  # Assuming mask images end with '_mask.png'
        source_path = os.path.join(source_folder, filename)
        destination_path = os.path.join(destination_folder, filename)
        shutil.move(source_path, destination_path)
        print(f"Moved {filename} to {destination_folder}")
# Out:
# Moved VID_20230823_175034032-2_mp4-531_jpg.rf.6c0e8433d76e433fe7703e1fabbab0b3_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-450_jpg.rf.8c048baa49f1b4de1922e9b78b5a676c_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-800_jpg.rf.eb6eee9d93145e1da59d6c3a70eda4ec_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-570_jpg.rf.95085652774a5054c4aea3666e230d6d_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-367_jpg.rf.bcaf9d6285eea5abf3c2275b9614d603_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-98_jpg.rf.5e61d3f9aebc11e1536726e0658c0626_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4
mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-495_jpg.rf.5a4435202396e4a2961ffe64ef4d8b09_mask.png to /content/mask
# Moved edsa_487_jpg.rf.d932b1b3f9502b047ea500120e05342b_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-373_jpg.rf.12f8e61a7f2fde35a003a552e887f563_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-739_jpg.rf.ecf993889b8555634ee6d85227b6ae2f_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-725_jpg.rf.bcbf4a0c77861cb62150682d1aa2fcd1_mask.png to /content/mask
# Moved edsa_92_jpg.rf.a300da3163f68e54c86fe7e49bf4fe26_mask.png to /content/mask
# Moved edsa_496_jpg.rf.782589e78802ee27c5a30307540e3a1d_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-67_jpg.rf.8ee7e7e109213b1939cbff7a5a45d001_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-277_jpg.rf.1c0bd1201a73087e39f081723ba2f570_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-282_jpg.rf.1678aa9caa164e513c6e1e180b787a41_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-664_jpg.rf.44aff78c0d85c065cdd7bcafdbd3914e_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-704_jpg.rf.6e8698026ba0da1b4ebdcea9c353837b_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-871_jpg.rf.e00484d58522b2e10f65e108e106a747_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-162_jpg.rf.25cd6c82eae5c7772bcd87913e1d3768_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-100_jpg.rf.659e91373d9584b596e1f1d5a7f8a09c_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-643_jpg.rf.89c588fbbfae0441b967a0484088d5c2_mask.png to /content/mask
# Moved edsa_490_jpg.rf.bdd224ee0e06bb84c51fefabda6d0569_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-674_jpg.rf.fb3154df0a6b82c78751abd18561c134_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-260_jpg.rf.45819fa738bfa2ac8bc84a9194bde583_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-50_jpg.rf.0a0bf649b46b8de31d73eb21cac82d24_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-48_jpg.rf.66ad36ae5dc315a2a3bd4c7db64aeec4_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-239_jpg.rf.d7c7a85ec0c553a819254ebad031b1a0_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-32_jpg.rf.68e264b7b9894a6b6168ad3bd5a5e326_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-238_jpg.rf.ea559d9847f636d1b18e6953d920e336_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-735_jpg.rf.58503ad73ac04ab0337d576e2c6972a3_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-280_jpg.rf.3aaac8e1b28ef51c2f6804d2c1af8dfb_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-534_jpg.rf.293e3e667f5a92e27e88bddd70d049e8_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-816_jpg.rf.742f8f04b4b433b160e979dc237feb62_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-519_jpg.rf.de944ac4ee0ffb597f46900a425d88e8_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-796_jpg.rf.e43e86601f5d51c89f07a0e84510ab43_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-209_jpg.rf.1e3dbcc3feccb792be87a7d154418dc3_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-233_jpg.rf.9df4249133bea8c50af6544a696f45f0_mask.png to /content/mask
# Moved edsa_489_jpg.rf.dd8d10659dfb872e545017b44b52d5ee_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-134_jpg.rf.d0067d4aa34cccdd1ffc0fcfa16c1825_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-764_jpg.rf.5de7365b1c006a20915c71cc58a66cd9_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-665_jpg.rf.b519cd9ec02659a33cd516ad3f91e6bc_mask.png to /content/mask
# Moved edsa_57_jpg.rf.7c5587e0fc35b6cff38e41f63a3b8eb5_mask.png to /content/mask
# Moved edsa_490_jpg.rf.4e011845483dd264a872124fe6007044_mask.png to /content/mask
# Moved VID_20230823_175034032-2_mp4-378_jpg.rf.f0d63006fda6c73ea60936648ab01d0b_mask.png to /content/mask

# %%
from keras.utils import normalize
import os
import glob
import cv2
import numpy as np
from matplotlib import pyplot as plt


#Resizing images, if needed
SIZE_X = 416
SIZE_Y = 416
n_classes=7#Number of classes for segmentation

#Capture training image info as a list
train_images = []

for directory_path in glob.glob("/content/unet_model-2/train/"):
    for img_path in glob.glob(os.path.join(directory_path, "*.jpg")):
        img = cv2.imread(img_path, 0)
        img = cv2.resize(img, (SIZE_Y, SIZE_X))
        train_images.append(img)


#Convert list to array for machine learning processing
train_images = np.array(train_images)

#Capture mask/label info as a list
train_masks = []
for directory_path in glob.glob("/content/mask"):
    for mask_path in glob.glob(os.path.join(directory_path, "*.png")):
        mask = cv2.imread(mask_path, 0)
        mask = cv2.resize(mask, (SIZE_Y, SIZE_X), interpolation = cv2.INTER_NEAREST)  #Otherwise ground truth changes due to interpolation
        train_masks.append(mask)

#Convert list to array for machine learning processing
train_masks = np.array(train_masks)

# %%
import random
img_number = random.randint(0, len(train_images)-1)
img = train_images[img_number]
mask = train_masks[img_number]


plt.figure(figsize=(12, 8))
plt.subplot(221)
plt.title('Image')
plt.imshow(img)
plt.subplot(222)
plt.title('Mask')
plt.imshow(mask)
plt.show()

# %%
train_masks.shape
train_images.shape
# Out:
# (1500, 416, 416)

# %% [markdown]
# # this is not windows

# %%
import glob
import cv2
image_names = glob.glob("/content/unet_model-2/train/*.jpg")
image_names.sort()
image_names = image_names[0:400]

# %%
print(image_names)
# Out:
# ['/content/unet_model-2/train/00-226-_jpg.rf.01249a81fbf1d75f4e0e30096e91463a.jpg', '/content/unet_model-2/train/00-226-_jpg.rf.2debc5a8fb6e418c792c48fcf07b6774.jpg', '/content/unet_model-2/train/00-226-_jpg.rf.67a2ce61f4798409873e82cf89bf4c9a.jpg', '/content/unet_model-2/train/00-226-_jpg.rf.7e05010948214935f0c4a24b4ae37a6a.jpg', '/content/unet_model-2/train/00-226-_jpg.rf.9452c15ada541dbc1d62c10c990b18d8.jpg', '/content/unet_model-2/train/00-226-_jpg.rf.cb3f9ab7946bf0705a1c1548a0b2f234.jpg', '/content/unet_model-2/train/00-227-_jpg.rf.17c50c6392a110f9908f2699d2ef1ec4.jpg', '/content/unet_model-2/train/00-227-_jpg.rf.3ca12f7b1d7f42f8eab0bde6eef5dc2a.jpg', '/content/unet_model-2/train/00-227-_jpg.rf.4b7f62f928dfeeecf8c0e2e6ff2cedae.jpg', '/content/unet_model-2/train/00-227-_jpg.rf.50f26faa0d11a05f5f2a18578083499e.jpg', '/content/unet_model-2/train/00-227-_jpg.rf.af0d0e0de824d9d48ce2db262a4a4bfa.jpg', '/content/unet_model-2/train/00-227-_jpg.rf.c8cbb445246dbd499930c690c00e8937.jpg', '/content/unet_model-2/train/00-228-_jpg.rf.0faf5d51df92dfdddf3c063907639487.jpg', '/content/unet_model-2/train/00-228-_jpg.rf.12acf29df759779cf54ef66ab18e6844.jpg', '/content/unet_model-2/train/00-228-_jpg.rf.21d234ea706b1073f53f1c4ed6fa3423.jpg', '/content/unet_model-2/train/00-228-_jpg.rf.2359af42f787904e8605d512ace8ea6a.jpg', '/content/unet_model-2/train/00-228-_jpg.rf.319a70508294b1b20d2df2d67329e8f4.jpg', '/content/unet_model-2/train/00-228-_jpg.rf.35502407f6076229ba38eace46315505.jpg', '/content/unet_model-2/train/00-228-_jpg.rf.496732ea66cd2e6e6b09f80cbd697a39.jpg', '/content/unet_model-2/train/00-228-_jpg.rf.630bdec926754399dda27ebe200536f9.jpg', '/content/unet_model-2/train/00-228-_jpg.rf.67d82b2ee01d31af76887db5b917fc25.jpg', '/content/unet_model-2/train/00-229-_jpg.rf.31ad2841a9c2039c1ad8ba7b2748e537.jpg', '/content/unet_model-2/train/00-229-_jpg.rf.8e5ad7b8a5f9beab11e81afa2d2fc586.jpg', '/content/unet_model-2/train/00-229-_jpg.rf.b8718c6d07a3229615714b086b4a62a0.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-100_jpg.rf.4642aee96b66720eec3e2553adfec648.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-100_jpg.rf.659e91373d9584b596e1f1d5a7f8a09c.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-100_jpg.rf.c3c5e8edc0c21d99d36263979c989a8e.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-102_jpg.rf.05cc64f0126fcf3141f2499ca63a6486.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-102_jpg.rf.35174e782dbe43d6e665cfb8409d479f.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-102_jpg.rf.a5ffe9807565b4186eac2c5e13d8f328.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-103_jpg.rf.93523b146e2cc242de380df56f5dcfbc.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-103_jpg.rf.d79472f7c1b91404c6dd64008f6ad52c.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-103_jpg.rf.e8f10c19be301ff11ee6eb53287525a5.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-104_jpg.rf.1e84230496f31ce647fd7f3a87494849.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-104_jpg.rf.74be9c1ae4493dd60893f9b6711bb219.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-104_jpg.rf.bf42cedaa8d076900177e75d1ee78e0e.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-109_jpg.rf.d3bc4552c2a3b42e93c8179e25f25f12.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-109_jpg.rf.d5df2abec7319938473fadca7251747a.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-109_jpg.rf.f6dae4dabc6efa41780c97e08dd61fd5.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-10_jpg.rf.22bb857631ef2f588ce7099f723af2e1.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-10_jpg.rf.434698bf4f9558f48feb62b4d5f64783.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-10_jpg.rf.5b4a7bdea5830d58ddbbc6400d8f0cce.jpg', '/content/unet_model-2/train/VID_20230823_175034032-2_mp4-113_jpg. ...

# %%
#images = [cv2.imread(image, 1) for image in image_names]
#image_dataset = np.array(images)

# %%
# Initialize an empty list to store resized images
resized_images = []

# Define the target size (416x416 pixels)
target_size = (416, 416)

# Loop through the list of image file paths
for image_path in image_names:
    # Read the image using OpenCV
    image = cv2.imread(image_path, 1)  # 1 for loading color image

    # Check if the image was successfully loaded
    if image is not None:
        # Resize the image to the target size
        resized_image = cv2.resize(image, target_size)

        # Append the resized image to the list
        resized_images.append(resized_image)

# Convert the list of resized images to a NumPy array
image_dataset = np.array(resized_images)

# %%
mask_names = glob.glob("/content/mask/*.png")
mask_names.sort()
mask_names = mask_names[0:400]

# %%
print(mask_names)
# Out:
# ['/content/mask/00-226-_jpg.rf.01249a81fbf1d75f4e0e30096e91463a_mask.png', '/content/mask/00-226-_jpg.rf.2debc5a8fb6e418c792c48fcf07b6774_mask.png', '/content/mask/00-226-_jpg.rf.67a2ce61f4798409873e82cf89bf4c9a_mask.png', '/content/mask/00-226-_jpg.rf.7e05010948214935f0c4a24b4ae37a6a_mask.png', '/content/mask/00-226-_jpg.rf.9452c15ada541dbc1d62c10c990b18d8_mask.png', '/content/mask/00-226-_jpg.rf.cb3f9ab7946bf0705a1c1548a0b2f234_mask.png', '/content/mask/00-227-_jpg.rf.17c50c6392a110f9908f2699d2ef1ec4_mask.png', '/content/mask/00-227-_jpg.rf.3ca12f7b1d7f42f8eab0bde6eef5dc2a_mask.png', '/content/mask/00-227-_jpg.rf.4b7f62f928dfeeecf8c0e2e6ff2cedae_mask.png', '/content/mask/00-227-_jpg.rf.50f26faa0d11a05f5f2a18578083499e_mask.png', '/content/mask/00-227-_jpg.rf.af0d0e0de824d9d48ce2db262a4a4bfa_mask.png', '/content/mask/00-227-_jpg.rf.c8cbb445246dbd499930c690c00e8937_mask.png', '/content/mask/00-228-_jpg.rf.0faf5d51df92dfdddf3c063907639487_mask.png', '/content/mask/00-228-_jpg.rf.12acf29df759779cf54ef66ab18e6844_mask.png', '/content/mask/00-228-_jpg.rf.21d234ea706b1073f53f1c4ed6fa3423_mask.png', '/content/mask/00-228-_jpg.rf.2359af42f787904e8605d512ace8ea6a_mask.png', '/content/mask/00-228-_jpg.rf.319a70508294b1b20d2df2d67329e8f4_mask.png', '/content/mask/00-228-_jpg.rf.35502407f6076229ba38eace46315505_mask.png', '/content/mask/00-228-_jpg.rf.496732ea66cd2e6e6b09f80cbd697a39_mask.png', '/content/mask/00-228-_jpg.rf.630bdec926754399dda27ebe200536f9_mask.png', '/content/mask/00-228-_jpg.rf.67d82b2ee01d31af76887db5b917fc25_mask.png', '/content/mask/00-229-_jpg.rf.31ad2841a9c2039c1ad8ba7b2748e537_mask.png', '/content/mask/00-229-_jpg.rf.8e5ad7b8a5f9beab11e81afa2d2fc586_mask.png', '/content/mask/00-229-_jpg.rf.b8718c6d07a3229615714b086b4a62a0_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-100_jpg.rf.4642aee96b66720eec3e2553adfec648_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-100_jpg.rf.659e91373d9584b596e1f1d5a7f8a09c_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-100_jpg.rf.c3c5e8edc0c21d99d36263979c989a8e_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-102_jpg.rf.05cc64f0126fcf3141f2499ca63a6486_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-102_jpg.rf.35174e782dbe43d6e665cfb8409d479f_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-102_jpg.rf.a5ffe9807565b4186eac2c5e13d8f328_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-103_jpg.rf.93523b146e2cc242de380df56f5dcfbc_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-103_jpg.rf.d79472f7c1b91404c6dd64008f6ad52c_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-103_jpg.rf.e8f10c19be301ff11ee6eb53287525a5_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-104_jpg.rf.1e84230496f31ce647fd7f3a87494849_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-104_jpg.rf.74be9c1ae4493dd60893f9b6711bb219_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-104_jpg.rf.bf42cedaa8d076900177e75d1ee78e0e_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-109_jpg.rf.d3bc4552c2a3b42e93c8179e25f25f12_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-109_jpg.rf.d5df2abec7319938473fadca7251747a_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-109_jpg.rf.f6dae4dabc6efa41780c97e08dd61fd5_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-10_jpg.rf.22bb857631ef2f588ce7099f723af2e1_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-10_jpg.rf.434698bf4f9558f48feb62b4d5f64783_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-10_jpg.rf.5b4a7bdea5830d58ddbbc6400d8f0cce_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-113_jpg.rf.596b771c45d55ca5c5a00a6a659963a5_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-113_jpg.rf.6e82eaada39ce662f2cec5732136acef_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-113_jpg.rf.b47efff517c1bc542cafa118ff1fc93c_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-116_jpg.rf.85c91f5e1e3ab329dd869e849905d002_mask.png', '/content/mask/VID_20230823_175034032-2_mp4-116_ ...

# %%
#masks = [cv2.imread(mask,0) for mask in mask_names]
#mask_dataset = np.array(masks)

# %%
# Initialize an empty list to store resized mask images
resized_masks = []

# Define the target size (e.g., 416x416 pixels)
target_size = (416, 416)

# Loop through the list of mask image file paths
for mask_path in mask_names:
    # Read the mask image using OpenCV
    mask_image = cv2.imread(mask_path, 0)  # 0 for loading grayscale image

    # Check if the mask image was successfully loaded
    if mask_image is not None:
        # Resize the mask image to the target size
        resized_mask = cv2.resize(mask_image, target_size)

        # Append the resized mask image to the list
        resized_masks.append(resized_mask)

# Convert the list of resized mask images to a NumPy array
mask_dataset = np.array(resized_masks)

# %%
image_dataset.shape
mask_dataset.shape
# Out:
# (400, 416, 416)

# %%
import numpy as np
np.unique(mask_dataset)
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=uint8)

# %%
# Sanity check...
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number])
plt.subplot(122)
plt.imshow(mask_dataset[image_number])
plt.show()

# %%
import random
img_number = random.randint(0, len(image_dataset)-1)
img = image_dataset[img_number]
mask = mask_dataset[img_number]
plt.figure(figsize=(12, 8))
plt.subplot(221)
plt.title('Image')
plt.imshow(img)
plt.subplot(222)
plt.title('Mask')
plt.imshow(mask)
plt.show()

# %%
###############################################
#Encode labels... but multi dim array so need to flatten, encode and reshape
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
n, h, w = mask_dataset.shape
train_masks_reshaped = mask_dataset.reshape(-1,1)
train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)

np.unique(train_masks_encoded_original_shape)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# array([0, 1, 2, 3, 4, 5, 6])

# %%
#############################################

#################################################
train_images = np.expand_dims(image_dataset, axis=3)
train_images = normalize(image_dataset, axis=1)

train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

#Create a subset of data for quick testing
#Picking 10% for testing and remaining for training
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, train_masks_input, test_size = 0.10, random_state = 0)


print("Class values in the dataset are ... ", np.unique(y_train.ravel()))


print(n)
print(h)
print(w)
# Out:
# Class values in the dataset are ...  [0 1 2 3 4 5 6]
# 400
# 416
# 416

# %%
from keras.utils import to_categorical

# Convert class labels to categorical representation
train_masks_cat = to_categorical(y_train, num_classes=n_classes)
y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))

test_masks_cat = to_categorical(y_test, num_classes=n_classes)
y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))

# %%
import tensorflow as tf

IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]


print(IMG_HEIGHT)
print(IMG_WIDTH)
print(IMG_CHANNELS)




def get_model():
    return multi_unet_model2(n_classes=n_classes, IMG_H=IMG_HEIGHT, IMG_W=IMG_WIDTH, IMG_CHANNELS=IMG_CHANNELS)

model = get_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

#If starting with pre-trained weights.
#model.load_weights('???.hdf5')
#Modelcheckpoint
checkpointer = tf.keras.callbacks.ModelCheckpoint('model_for_nuclei.h5', verbose=1, save_best_only=True)

callbacks = [tf.keras.callbacks.TensorBoard(log_dir='logs')]



history = model.fit(X_train, y_train_cat,
                    batch_size = 4,
                    verbose=1,
                    epochs=100,
                    validation_data=(X_test, y_test_cat),
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    shuffle=False)
# Out:
# 416
# 416
# 3
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27018416/27018416 [==============================] - 0s 0us/step
# (None, 104, 104, 144)
# (None, 208, 208, 144)
# (None, 416, 416, 72)
# (None, 416, 416, 3)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 416, 416, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 416, 416, 3)          0         ['input_1[0][0]']
#
#  normalization (Normalizati  (None, 416, 416, 3)          7         ['rescaling[0][0]']
#  on)
#
#  rescaling_1 (Rescaling)     (None, 416, 416, 3)          0         ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 417, 417, 3)          0         ['rescaling_1[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 208, 208, 32)         864       ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 208, 208, 32)         128       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 208, 208, 32)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 208, 208, 32)         288       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 208, 208, 32)         128       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 208, 208, 32)         0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 32)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 32)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 8)              264       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 32)             288       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 208, 208, 32)         0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 208, 208, 16)         512       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 208, 208, 16)         64        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 208, 208, 16)         144       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 208, 208, 16)         64        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 208, 208, 16)         0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 16)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 16)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 4)              68        ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 16)             80        ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 208, 208, 16)         0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 208, 208, 16)         256       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 208, 208, 16)         64        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 208, 208, 16)         0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 208, 208, 16)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 208, 208, 96)         1536      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 208, 208, 96)         384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 208, 208, 96)         0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 209, 209, 96)         0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 104, 104, 96)         864       ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 104, 104, 96)         384       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 104, 104, 96)         0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 96)                   0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 96)             0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 4)              388       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 96)             480       ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 104, 104, 96)         0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 104, 104, 24)         2304      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 104, 104, 24)         96        ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 104, 104, 144)        3456      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 104, 104, 144)        576       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 104, 104, 144)        0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 104, 104, 144)        1296      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 104, 104, 144)        576       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 104, 104, 144)        0         ['block2b_bn[0][0]']
#  tion)
#
#  conv2d_transpose (Conv2DTr  (None, 208, 208, 144)        83088     ['block2b_activation[0][0]']
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 416, 416, 72)         41544     ['conv2d_transpose[0][0]']
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 416, 416, 3)          867       ['conv2d_transpose_1[0][0]']
#  Transpose)
#
#  conv2d (Conv2D)             (None, 416, 416, 16)         448       ['conv2d_transpose_2[0][0]']
#
#  dropout (Dropout)           (None, 416, 416, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 416, 416, 16)         2320      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 208, 208, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 208, 208, 32)         4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 208, 208, 32)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 208, 208, 32)         9248      ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 104, 104, 32)         0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 104, 104, 64)         18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 104, 104, 64)         0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 104, 104, 64)         36928     ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 52, 52, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 52, 52, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 52, 52, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 52, 52, 128)          147584    ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 26, 26, 128)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 26, 26, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 26, 26, 256)          0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 26, 26, 256)          590080    ['dropout_4[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 52, 52, 128)          131200    ['conv2d_9[0][0]']
#  Transpose)
#
#  concatenate (Concatenate)   (None, 52, 52, 256)          0         ['conv2d_transpose_3[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 52, 52, 128)          295040    ['concatenate[0][0]']
#
#  dropout_5 (Dropout)         (None, 52, 52, 128)          0         ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 52, 52, 128)          147584    ['dropout_5[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 104, 104, 64)         32832     ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 104, 104, 128)        0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 104, 104, 64)         73792     ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 104, 104, 64)         0         ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 104, 104, 64)         36928     ['dropout_6[0][0]']
#
#  conv2d_transpose_5 (Conv2D  (None, 208, 208, 32)         8224      ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 208, 208, 64)         0         ['conv2d_transpose_5[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 208, 208, 32)         18464     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 208, 208, 32)         0         ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 208, 208, 32)         9248      ['dropout_7[0][0]']
#
#  conv2d_transpose_6 (Conv2D  (None, 416, 416, 16)         2064      ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 416, 416, 32)         0         ['conv2d_transpose_6[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 416, 416, 16)         4624      ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 416, 416, 16)         0         ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 416, 416, 16)         2320      ['dropout_8[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 416, 416, 7)          119       ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 2082265 (7.94 MB)
# Trainable params: 2081026 (7.94 MB)
# Non-trainable params: 1239 (4.84 KB)
# __________________________________________________________________________________________________
# Epoch 1/100
# 90/90 [==============================] - 57s 294ms/step - loss: 0.3426 - accuracy: 0.9193 - val_loss: 0.2510 - val_accuracy: 0.9273
# Epoch 2/100
# 90/90 [==============================] - 26s 284ms/step - loss: 0.2248 - accuracy: 0.9342 - val_loss: 0.1999 - val_accuracy: 0.9273
# Epoch 3/100
# 90/90 [==============================] - 33s 362ms/step - loss: 0.2040 - accuracy: 0.9344 - val_loss: 0.1920 - val_accuracy: 0.9277
# Epoch 4/100
# 90/90 [==============================] - 25s 280ms/step - loss: 0.1889 - accuracy: 0.9424 - val_loss: 0.1535 - val_accuracy: 0.9580
# Epoch 5/100
# 90/90 [==============================] - 25s 282ms/step - loss: 0.1719 - accuracy: 0.9488 - val_loss: 0.1310 - val_accuracy: 0.9655
# Epoch 6/100
# 90/90 [==============================] - 25s 281ms/step - loss: 0.1530 - accuracy: 0.9541 - val_loss: 0.1120 - val_accuracy: 0.9701
# Epoch 7/100
# 90/90 [==============================] - 25s 280ms/step - loss: 0.1361 - accuracy: 0.9581 - val_loss: 0.1061 - val_accuracy: 0.9716
# Epoch 8/100
# 90/90 [==============================] - 25s 281ms/step - loss: 0.1229 - accuracy: 0.9607 - val_loss: 0.0988 - val_accuracy: 0.9727
# Epoch 9/100
# 90/90 [==============================] - 26s 288ms/step - loss: 0.1163 - accuracy: 0.9616 - val_loss: 0.0948 - val_accuracy: 0.9740
# Epoch 10/100
# 90/90 [==============================] - 25s 281ms/step - loss: 0.1106 - accuracy: 0.9628 - val_loss: 0.1059 - val_accuracy: 0.9733
# Epoch 11/100
# 90/90 [==============================] - 26s 286ms/step - loss: 0.1058 - accuracy: 0.9635 - val_loss: 0.1548 - val_accuracy: 0.9705
# Epoch 12/100
# 90/90 [==============================] - 25s 279ms/step - loss: 0.0994 - accuracy: 0.9645 - val_loss: 0.0856 - val_accuracy: 0.9769
# Epoch 13/100
# 90/90 [==============================] - 25s 279ms/step - loss: 0.0935 - accuracy: 0.9654 - val_loss: 0.0919 - val_accuracy: 0.9761
# Epoch 14/100
# 90/90 [==============================] - 25s 279ms/step - loss: 0.0892 - accuracy: 0.9668 - val_loss: 0.0893 - val_accuracy: 0.9754
# Epoch 15/100
# 90/90 [==============================] - 26s 286ms/step - loss: 0.0881 - accuracy: 0.9675 - val_loss: 0.0840 - val_accuracy: 0.9778
# Epoch 16/100
# 90/90 [==============================] - 25s 279ms/step - loss: 0.0800 - accuracy: 0.9696 - val_loss: 0.0810 - val_accuracy: 0.9777
# Epoch 17/100
# 90/90 [==============================] - 25s 279ms/step - loss: 0.0750 - accuracy: 0.9718 - val_loss: 0.0743 - val_accuracy: 0.9804
# Epoch 18/100
# 90/90 [==============================] - 25s 279ms/step - loss: 0.0757 - accuracy: 0.9720 - val_loss: 0.0800 - val_accuracy: 0.9788
# Epoch 19/100
# 90/90 [==============================] - 26s 287ms/step - loss: 0.0762 - accuracy: 0.9727 - val_loss: 0.0831 - val_accuracy: 0.9768
# Epoch 20/100
# 90/90 [==============================] - 25s 280ms/step - loss: 0.0768 - accuracy: 0.9714 - val_loss: 0.0762 - val_accuracy: 0.9796
# Epoch 21/100
# 90/90 [==============================] - 25s 279ms/step - loss: 0.0685 - accuracy: 0.9748 - val_loss: 0.0762 - val_accuracy: 0.9794
# Epoch 22/100
# 90/90 [==============================] - 25s 279ms/step - loss: 0.0673 - accuracy: 0.9760 - val_loss: 0.0795 - val_accuracy: 0.9795
# Epoch 23/100
# 90/90 [==============================] - 25s 278ms/step - loss: 0.0692 - accuracy: 0.9752 - val_loss: 0.0806 - val_accuracy: 0.9782
# Epoch 24/100
# 90/90 [==============================] - 25s 279ms/step - loss: 0.0711 - accuracy: 0.9754 - val_loss: 0.0837 - val_accuracy: 0.9765
# Epoch 25/100
# 90/90 [==============================] - 25s 278ms/step - loss: 0.0653 - accuracy: 0.9774 - val_loss: 0.1080 - val_accuracy: 0.9704
# Epoch 26/100
# 90/90 [==============================] - 26s 285ms/step - loss: 0.0723 - accuracy: 0.9750 - val_loss: 0.1117 - val_accuracy: 0.9705
# Epoch 27/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0687 - accuracy: 0.9762 - val_loss: 0.0670 - val_accuracy: 0.9813
# Epoch 28/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0647 - accuracy: 0.9768 - val_loss: 0.0630 - val_accuracy: 0.9843
# Epoch 29/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0596 - accuracy: 0.9792 - val_loss: 0.0665 - val_accuracy: 0.9827
# Epoch 30/100
# 90/90 [==============================] - 26s 284ms/step - loss: 0.0598 - accuracy: 0.9794 - val_loss: 0.0734 - val_accuracy: 0.9797
# Epoch 31/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0534 - accuracy: 0.9821 - val_loss: 0.0590 - val_accuracy: 0.9841
# Epoch 32/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0484 - accuracy: 0.9838 - val_loss: 0.0687 - val_accuracy: 0.9820
# Epoch 33/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0484 - accuracy: 0.9839 - val_loss: 0.0578 - val_accuracy: 0.9845
# Epoch 34/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0505 - accuracy: 0.9834 - val_loss: 0.0573 - val_accuracy: 0.9852
# Epoch 35/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0512 - accuracy: 0.9829 - val_loss: 0.0571 - val_accuracy: 0.9860
# Epoch 36/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0494 - accuracy: 0.9835 - val_loss: 0.0623 - val_accuracy: 0.9855
# Epoch 37/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0485 - accuracy: 0.9836 - val_loss: 0.0755 - val_accuracy: 0.9801
# Epoch 38/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0500 - accuracy: 0.9838 - val_loss: 0.0666 - val_accuracy: 0.9847
# Epoch 39/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0477 - accuracy: 0.9843 - val_loss: 0.0832 - val_accuracy: 0.9826
# Epoch 40/100
# 90/90 [==============================] - 25s 283ms/step - loss: 0.0469 - accuracy: 0.9845 - val_loss: 0.0633 - val_accuracy: 0.9852
# Epoch 41/100
# 90/90 [==============================] - 25s 283ms/step - loss: 0.0467 - accuracy: 0.9844 - val_loss: 0.0722 - val_accuracy: 0.9817
# Epoch 42/100
# 90/90 [==============================] - 25s 275ms/step - loss: 0.0466 - accuracy: 0.9848 - val_loss: 0.0626 - val_accuracy: 0.9848
# Epoch 43/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0416 - accuracy: 0.9868 - val_loss: 0.0771 - val_accuracy: 0.9812
# Epoch 44/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0432 - accuracy: 0.9861 - val_loss: 0.0642 - val_accuracy: 0.9858
# Epoch 45/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0378 - accuracy: 0.9873 - val_loss: 0.0620 - val_accuracy: 0.9870
# Epoch 46/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0341 - accuracy: 0.9890 - val_loss: 0.0573 - val_accuracy: 0.9865
# Epoch 47/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0350 - accuracy: 0.9888 - val_loss: 0.0668 - val_accuracy: 0.9840
# Epoch 48/100
# 90/90 [==============================] - 25s 275ms/step - loss: 0.0318 - accuracy: 0.9898 - val_loss: 0.0590 - val_accuracy: 0.9869
# Epoch 49/100
# 90/90 [==============================] - 26s 284ms/step - loss: 0.0307 - accuracy: 0.9902 - val_loss: 0.0604 - val_accuracy: 0.9868
# Epoch 50/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0346 - accuracy: 0.9890 - val_loss: 0.0596 - val_accuracy: 0.9872
# Epoch 51/100
# 90/90 [==============================] - 25s 278ms/step - loss: 0.0306 - accuracy: 0.9902 - val_loss: 0.0523 - val_accuracy: 0.9876
# Epoch 52/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0317 - accuracy: 0.9899 - val_loss: 0.0532 - val_accuracy: 0.9870
# Epoch 53/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0617 - accuracy: 0.9817 - val_loss: 0.1072 - val_accuracy: 0.9771
# Epoch 54/100
# 90/90 [==============================] - 25s 283ms/step - loss: 0.0513 - accuracy: 0.9833 - val_loss: 0.0626 - val_accuracy: 0.9861
# Epoch 55/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0346 - accuracy: 0.9891 - val_loss: 0.0559 - val_accuracy: 0.9874
# Epoch 56/100
# 90/90 [==============================] - 26s 284ms/step - loss: 0.0354 - accuracy: 0.9888 - val_loss: 0.0655 - val_accuracy: 0.9874
# Epoch 57/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0336 - accuracy: 0.9896 - val_loss: 0.0501 - val_accuracy: 0.9873
# Epoch 58/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0314 - accuracy: 0.9901 - val_loss: 0.0508 - val_accuracy: 0.9878
# Epoch 59/100
# 90/90 [==============================] - 25s 275ms/step - loss: 0.0314 - accuracy: 0.9897 - val_loss: 0.0477 - val_accuracy: 0.9875
# Epoch 60/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0338 - accuracy: 0.9894 - val_loss: 0.0640 - val_accuracy: 0.9851
# Epoch 61/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0292 - accuracy: 0.9907 - val_loss: 0.0596 - val_accuracy: 0.9868
# Epoch 62/100
# 90/90 [==============================] - 25s 283ms/step - loss: 0.0270 - accuracy: 0.9914 - val_loss: 0.0493 - val_accuracy: 0.9882
# Epoch 63/100
# 90/90 [==============================] - 25s 283ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.0588 - val_accuracy: 0.9878
# Epoch 64/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0267 - accuracy: 0.9915 - val_loss: 0.0560 - val_accuracy: 0.9878
# Epoch 65/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0251 - accuracy: 0.9919 - val_loss: 0.0552 - val_accuracy: 0.9875
# Epoch 66/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0392 - accuracy: 0.9878 - val_loss: 0.0591 - val_accuracy: 0.9851
# Epoch 67/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0335 - accuracy: 0.9893 - val_loss: 0.0607 - val_accuracy: 0.9865
# Epoch 68/100
# 90/90 [==============================] - 25s 283ms/step - loss: 0.0267 - accuracy: 0.9915 - val_loss: 0.0560 - val_accuracy: 0.9870
# Epoch 69/100
# 90/90 [==============================] - 25s 282ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.0551 - val_accuracy: 0.9879
# Epoch 70/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0219 - accuracy: 0.9929 - val_loss: 0.0544 - val_accuracy: 0.9883
# Epoch 71/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0209 - accuracy: 0.9932 - val_loss: 0.0541 - val_accuracy: 0.9887
# Epoch 72/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0212 - accuracy: 0.9931 - val_loss: 0.0533 - val_accuracy: 0.9886
# Epoch 73/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0213 - accuracy: 0.9929 - val_loss: 0.0561 - val_accuracy: 0.9881
# Epoch 74/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0216 - accuracy: 0.9929 - val_loss: 0.0557 - val_accuracy: 0.9880
# Epoch 75/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0199 - accuracy: 0.9934 - val_loss: 0.0539 - val_accuracy: 0.9881
# Epoch 76/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0191 - accuracy: 0.9936 - val_loss: 0.0569 - val_accuracy: 0.9885
# Epoch 77/100
# 90/90 [==============================] - 25s 283ms/step - loss: 0.0184 - accuracy: 0.9939 - val_loss: 0.0558 - val_accuracy: 0.9882
# Epoch 78/100
# 90/90 [==============================] - 26s 284ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 0.0561 - val_accuracy: 0.9885
# Epoch 79/100
# 90/90 [==============================] - 26s 284ms/step - loss: 0.0279 - accuracy: 0.9910 - val_loss: 0.0988 - val_accuracy: 0.9785
# Epoch 80/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0761 - accuracy: 0.9759 - val_loss: 0.0710 - val_accuracy: 0.9838
# Epoch 81/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0578 - accuracy: 0.9808 - val_loss: 0.0698 - val_accuracy: 0.9846
# Epoch 82/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0385 - accuracy: 0.9874 - val_loss: 0.0587 - val_accuracy: 0.9870
# Epoch 83/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0278 - accuracy: 0.9910 - val_loss: 0.0554 - val_accuracy: 0.9882
# Epoch 84/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0252 - accuracy: 0.9918 - val_loss: 0.0550 - val_accuracy: 0.9879
# Epoch 85/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0288 - accuracy: 0.9906 - val_loss: 0.0535 - val_accuracy: 0.9877
# Epoch 86/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0288 - accuracy: 0.9910 - val_loss: 0.0513 - val_accuracy: 0.9876
# Epoch 87/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.0591 - val_accuracy: 0.9875
# Epoch 88/100
# 90/90 [==============================] - 25s 277ms/step - loss: 0.0236 - accuracy: 0.9923 - val_loss: 0.0628 - val_accuracy: 0.9882
# Epoch 89/100
# 90/90 [==============================] - 26s 284ms/step - loss: 0.0327 - accuracy: 0.9904 - val_loss: 0.0637 - val_accuracy: 0.9840
# Epoch 90/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0282 - accuracy: 0.9906 - val_loss: 0.0599 - val_accuracy: 0.9862
# Epoch 91/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0232 - accuracy: 0.9923 - val_loss: 0.0607 - val_accuracy: 0.9879
# Epoch 92/100
# 90/90 [==============================] - 25s 276ms/step - loss: 0.0213 - accuracy: 0.9930 - val_loss: 0.0568 - val_accuracy: 0.9881
# Epoch 93/100
#  1/90 [..............................] - ETA: 23s - loss: 0.0328 - accuracy: 0.9892

# %%
model.save('modified_unet.hdf5')
#model.save('sandstone_50_epochs_catXentropy_acc_with_weights.hdf5')
############################################################
#Evaluate the model
	# evaluate model
_, acc = model.evaluate(X_test, y_test_cat)
print("Accuracy is = ", (acc * 100.0), "%")


###
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Replace 'acc' with 'accuracy' for training and validation accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 2/2 [==============================] - 8s 2s/step - loss: 0.0896 - accuracy: 0.9830
# Accuracy is =  98.29975366592407 %

# %%
from keras.models import load_model
import tensorflow as tf
# Save the model in the SavedModel format
tf.saved_model.save(model, 'modified_unet_saved_model')

# Load the saved model
loaded_model = tf.saved_model.load('modified_unet_saved_model')


#model.save('sandstone_50_epochs_catXentropy_acc_with_weights.hdf5')
############################################################
#Evaluate the model
	# evaluate model
_, acc = model.evaluate(X_test, y_test_cat)
print("Accuracy is = ", (acc * 100.0), "%")


###
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Replace 'acc' with 'accuracy' for training and validation accuracy
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 1s 70ms/step - loss: 0.0896 - accuracy: 0.9830
# Accuracy is =  98.29975366592407 %

# %%
# !pip install pydot
# !sudo apt-get install graphviz
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model

# Load the model
model = load_model('/content/modified_unet.hdf5')  # Load your model here

# Plot the model architecture
plot_model(model, to_file='model_architecture.png', show_shapes=True)
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot) (2.4.7)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.

# %%
##################################
model = get_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.load_weights('/content/test.hdf5')
#model.load_weights('sandstone_50_epochs_catXentropy_acc_with_weights.hdf5')
checkpointer = tf.keras.callbacks.ModelCheckpoint('model_for_nuclei.h5', verbose=1, save_best_only=True)

callbacks = [tf.keras.callbacks.TensorBoard(log_dir='logs')]




history = model.fit(X_train, y_train_cat,
                    batch_size = 8,
                    verbose=1,
                    epochs=5,
                    validation_data=(X_test, y_test_cat),
                    #class_weight=class_weights,
                    callbacks=callbacks,
                    shuffle=False)


#######################################################################
# Out:
# Epoch 1/5
# 34/34 [==============================] - 16s 284ms/step - loss: 0.5910 - accuracy: 0.9250 - val_loss: 1.0812 - val_accuracy: 0.9159
# Epoch 2/5
# 34/34 [==============================] - 9s 255ms/step - loss: 0.4793 - accuracy: 0.9264 - val_loss: 0.9196 - val_accuracy: 0.9159
# Epoch 3/5
# 34/34 [==============================] - 9s 265ms/step - loss: 0.4362 - accuracy: 0.9262 - val_loss: 0.7384 - val_accuracy: 0.9159
# Epoch 4/5
# 34/34 [==============================] - 9s 265ms/step - loss: 0.4230 - accuracy: 0.9264 - val_loss: 0.6099 - val_accuracy: 0.9159
# Epoch 5/5
# 34/34 [==============================] - 9s 263ms/step - loss: 0.3820 - accuracy: 0.9264 - val_loss: 0.6084 - val_accuracy: 0.9159

# %%
y_pred = model.predict(X_test)
y_pred_argmax = np.argmax(y_pred, axis=3)

from keras.metrics import MeanIoU
IOU_keras = MeanIoU(num_classes=n_classes)
IOU_keras.update_state(y_test[:, :, :, 0], y_pred_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# 2/2 [==============================] - 2s 223ms/step
# Mean IoU = 0.39145824

# %%
values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)
class_IoUs = []

for i in range(n_classes):
    IoU = values[i, i] / (np.sum(values[i, :]) + np.sum(values[:, i]) - values[i, i])
    class_IoUs.append(IoU)
    print(f"IoU for class {i + 1} is: {IoU}")
# Out:
# IoU for class 1 is: 0.9849134087562561
# IoU for class 2 is: 0.1040114313364029
# IoU for class 3 is: 0.0
# IoU for class 4 is: 0.1693219542503357
# IoU for class 5 is: 0.8784481287002563
# IoU for class 6 is: 0.6035126447677612
# IoU for class 7 is: 0.0

# %%
import random
import matplotlib.pyplot as plt

# Randomly select a test image
test_img_number = random.randint(0, len(X_test))
test_img = X_test[test_img_number]
ground_truth = y_test[test_img_number]

# Expand the dimensions to (1, x, y, 3) to represent a single color image
test_img = np.expand_dims(test_img, axis=0)

# Predict using the model
y_pred = model.predict(test_img)
y_pred_argmax = np.argmax(y_pred, axis=3)[0]

# Display the images
plt.figure(figsize=(12, 8))

plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[0], cmap='gray')  # Display the color image
plt.axis('off')

plt.subplot(232)
plt.title('Ground Truth Label')
plt.imshow(ground_truth[:, :, 0], cmap='jet')
plt.axis('off')

plt.subplot(233)
plt.title('Prediction on Test Image')
plt.imshow(y_pred_argmax, cmap='jet')
plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 1s 760ms/step

# %%
# Create an RGB version of the predicted mask (assuming class labels)
y_pred_rgb = np.zeros((y_pred_argmax.shape[0], y_pred_argmax.shape[1], 3), dtype=np.uint8)
y_pred_rgb[y_pred_argmax == 0] = [0, 0, 0]         # Class 0 (background)
y_pred_rgb[y_pred_argmax == 1] = [0, 255, 0]       # Class 1 (red)

# Blend the original image with the segmented mask
alpha = 0.6  # Adjust the alpha value for blending
overlay = cv2.addWeighted(test_img[0], alpha, y_pred_rgb, 1 - alpha, 0)

# Display the images
plt.figure(figsize=(12, 8))

plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img[0], cmap='gray')  # Display the color image
plt.axis('off')

plt.subplot(232)
plt.title('Ground Truth Label')
plt.imshow(ground_truth[:, :, 0], cmap='jet')
plt.axis('off')

plt.subplot(233)
plt.title('Prediction on Test Image')
plt.imshow(y_pred_argmax, cmap='jet')
plt.axis('off')

plt.subplot(234)
plt.title('Overlay')
plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.show()

# %%
# Assuming you have 7 classes
num_classes = 7

# Map class labels to colors
class_colors = {
    0: [0, 0, 0],    # Background (Black)
    1: [255, 0, 0],  # Class 1 (Red)
    2: [0, 255, 0],  # Class 2 (Green)
    3: [0, 0, 255],  # Class 3 (Blue)
    4: [255, 255, 0],  # Class 4 (Yellow)
    5: [255, 0, 255],  # Class 5 (Magenta)
    6: [0, 255, 255],  # Class 6 (Cyan)
}

# Function to convert class labels to color image
def label_to_color_image(label):
    color_image = np.zeros((label.shape[0], label.shape[1], 3), dtype=np.uint8)
    for class_label, color in class_colors.items():
        mask = (label == class_label)
        color_image[mask] = color
    return color_image



import cv2

# Assuming 'original_image' is the original image (3 channels)
original_image = X_test[5]
ground_truth_mask = y_test[5][:, :, 0]

# Expand the dimensions to (1, x, y, 3) to represent a single color image
test_img = np.expand_dims(original_image, axis=0)

# Predict using the model
y_pred = model.predict(test_img)
y_pred_argmax = np.argmax(y_pred, axis=3)[0]


# Convert predicted mask to color image
predicted_mask_color = label_to_color_image(y_pred_argmax)

# Blend the original image and the predicted mask
overlay_predicted = cv2.addWeighted(original_image, 0.6, predicted_mask_color, 0.4, 0)

# Convert ground truth mask to color image
ground_truth_mask_color = label_to_color_image(ground_truth_mask)

# Blend the original image and the ground truth mask
overlay_ground_truth = cv2.addWeighted(original_image, 0.6, ground_truth_mask_color, 0.4, 0)

# Display the images
plt.figure(figsize=(18, 12))

plt.subplot(231)
plt.title('Original Image')
plt.imshow(original_image)
plt.axis('off')

plt.subplot(232)
plt.title('Ground Truth Mask')
plt.imshow(ground_truth_mask_color)
plt.axis('off')

plt.subplot(233)
plt.title('Predicted Mask')
plt.imshow(predicted_mask_color)
plt.axis('off')

plt.subplot(234)
plt.title('Overlay: Original and Predicted Masks')
plt.imshow(overlay_predicted)
plt.axis('off')

plt.subplot(235)
plt.title('Overlay: Original Image and Ground Truth Mask')
plt.imshow(overlay_ground_truth)
plt.axis('off')

plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %% [markdown]
# #approach for better training

# %%
#Apply a trained model on large image
# !pip install patchify
from patchify import patchify, unpatchify

large_image = cv2.imread('/content/licence_plate_segmentation_india-1/train/0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740-jpg_jpeg.rf.38ff3d55fe0ff458f77f962af5c7fd43.jpg', 0)
#This will split the image into small images of shape [3,3]
patches = patchify(large_image, (128, 128), step=128)  #Step=256 for 256 patches means no overlap

predicted_patches = []
for i in range(patches.shape[0]):
    for j in range(patches.shape[1]):
        print(i,j)

        single_patch = patches[i,j,:,:]
        single_patch_norm = np.expand_dims(normalize(np.array(single_patch), axis=1),2)
        single_patch_input=np.expand_dims(single_patch_norm, 0)
        # Define the new dimensions (e.g., 416x416)
        new_height = 416
        new_width = 416

        # Resize the image
        single_patch_input = cv2.resize(single_patch_input[0], (new_width, new_height))

        single_patch_prediction = (model.predict(single_patch_input))
        single_patch_predicted_img=np.argmax(single_patch_prediction, axis=3)[0,:,:]

        predicted_patches.append(single_patch_predicted_img)

predicted_patches = np.array(predicted_patches)

predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], 128,128) )

reconstructed_image = unpatchify(predicted_patches_reshaped, large_image.shape)
plt.imshow(reconstructed_image, cmap='gray')
#plt.imsave('data/results/segm.jpg', reconstructed_image, cmap='gray')

plt.hist(reconstructed_image.flatten())  #Threshold everything above 0

# final_prediction = (reconstructed_image > 0.01).astype(np.uint8)
# plt.imshow(final_prediction)

plt.figure(figsize=(8, 8))
plt.subplot(221)
plt.title('Large Image')
plt.imshow(large_image, cmap='gray')
plt.subplot(222)
plt.title('Prediction of large Image')
plt.imshow(reconstructed_image, cmap='jet')
plt.show()
# Out:
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from patchify) (1.23.5)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3
# 0 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-f823a5e783f8> in <cell line: 10>()
#      22         single_patch_input = cv2.resize(single_patch_input[0], (new_width, new_height))
#      23
# ---> 24         single_patch_prediction = (model.predict(single_patch_input))
#      25         single_patch_predicted_img=np.argmax(single_patch_prediction, axis=3)[0,:,:]
#      26
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2341, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2327, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2315, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2283, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 253, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer 'model_3' (type Functional).
#
#     Input 0 of layer "conv2d_57" is incompatible with the layer: expected min_ndim=4, found ndim=2. Full shape received: (32, 416)
#
#     Call arguments received by layer 'model_3' (type Functional):
#       • inputs=tf.Tensor(shape=(32, 416), dtype=float32)
#       • training=False
#       • mask=None

# %%
model.save('test_final_200.hdf5')
# Out:
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.

# %%
model = get_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.load_weights('/content/modified_unet.hdf5')




# Read the image using OpenCV
resized_images1 = []  # Initialize an empty list to store resized images
image_path1 = "/content/1537136116392.jpg"
image = cv2.imread(image_path1, 1)  # 1 for loading color image

# Check if the image was successfully loaded
if image is not None:
    # Resize the image to the target size
    resized_image = cv2.resize(image, target_size)

    # Append the resized image to the list
    resized_images1.append(resized_image)

# Convert the list of resized images to a NumPy array
test_img = np.array(resized_images1)

# Expand the dimensions to (1, x, y, 3) to represent a single color image
#test_img = np.expand_dims(test_img, axis=0)
print(test_img.shape)
# Predict using the model
y_pred = model.predict(test_img)
y_pred_argmax = np.argmax(y_pred, axis=3)[0]

import cv2

# Assuming 'original_image' is the original image (3 channels)
original_image = test_img[0]

# Convert predicted mask to color image
predicted_mask_color = np.zeros((y_pred_argmax.shape[0], y_pred_argmax.shape[1], 3), dtype=np.uint8)

# Define color mappings for each class
class_colors = {
    0: [0, 0, 0],    # Background (Black)
    1: [255, 0, 0],  # Class 1 (Red)
    2: [0, 255, 0],  # Class 2 (Green)
    3: [0, 0, 255],  # Class 3 (Blue)
    4: [255, 255, 0],  # Class 4 (Yellow)
    5: [255, 0, 255],  # Class 5 (Magenta)
    6: [0, 255, 255],  # Class 6 (Cyan)
}

# Map class labels to colors in the predicted mask
for class_label, color in class_colors.items():
    predicted_mask_color[y_pred_argmax == class_label] = color

# Blend the original image and the predicted mask
alpha = 0.6  # Adjust the alpha value for blending
overlay = cv2.addWeighted(original_image, alpha, predicted_mask_color, 1 - alpha, 0)

# Display the images
plt.figure(figsize=(12, 8))

plt.subplot(231)
plt.title('Testing Image')
plt.imshow(original_image)
plt.axis('off')

plt.subplot(233)
plt.title('Prediction on Test Image')
plt.imshow(y_pred_argmax, cmap='jet')
plt.axis('off')

plt.subplot(234)
plt.title('Overlay')
plt.imshow(cv2.cvtColor(overlay, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.show()
# Out:
# (1, 416, 416, 3)
# 1/1 [==============================] - 0s 389ms/step
